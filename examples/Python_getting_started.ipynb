# %% [markdown]
# # Simple Python examples for SYNERGY dataset
#
# Start with importing `Dataset` and `iter_datasets`.

# %%
from pprint import pprint

from synergy_dataset import Dataset, iter_datasets

# %% [markdown]
# ## Get each dataset as pandas DataFrame

# %%
for d in iter_datasets():

    df = d.to_frame()

    print(d.name, type(df))
# Out:
# Appenzeller-Herzog_2019 <class 'pandas.core.frame.DataFrame'>
# Bos_2018 <class 'pandas.core.frame.DataFrame'>
# Brouwer_2019 <class 'pandas.core.frame.DataFrame'>
# Chou_2003 <class 'pandas.core.frame.DataFrame'>
# Chou_2004 <class 'pandas.core.frame.DataFrame'>
# Donners_2021 <class 'pandas.core.frame.DataFrame'>
# Hall_2012 <class 'pandas.core.frame.DataFrame'>
# Jeyaraman_2020 <class 'pandas.core.frame.DataFrame'>
# Leenaars_2019 <class 'pandas.core.frame.DataFrame'>
# Leenaars_2020 <class 'pandas.core.frame.DataFrame'>
# Meijboom_2021 <class 'pandas.core.frame.DataFrame'>
# Menon_2022 <class 'pandas.core.frame.DataFrame'>
# Moran_2021 <class 'pandas.core.frame.DataFrame'>
# Muthu_2021 <class 'pandas.core.frame.DataFrame'>
# Nelson_2002 <class 'pandas.core.frame.DataFrame'>
# Oud_2018 <class 'pandas.core.frame.DataFrame'>
# Radjenovic_2013 <class 'pandas.core.frame.DataFrame'>
# Sep_2021 <class 'pandas.core.frame.DataFrame'>
# Smid_2020 <class 'pandas.core.frame.DataFrame'>
# van_de_Schoot_2018 <class 'pandas.core.frame.DataFrame'>
# van_der_Valk_2021 <class 'pandas.core.frame.DataFrame'>
# van_der_Waal_2022 <class 'pandas.core.frame.DataFrame'>
# van_Dis_2020 <class 'pandas.core.frame.DataFrame'>
# Walker_2018 <class 'pandas.core.frame.DataFrame'>
# Wassenaar_2017 <class 'pandas.core.frame.DataFrame'>
# Wolters_2018 <class 'pandas.core.frame.DataFrame'>

# %%
df.head()
# Out:
#                                                                                 doi  \
# openalex_id
# https://openalex.org/W2478209357  https://doi.org/10.1016/j.resuscitation.2016.0...
# https://openalex.org/W2095179087         https://doi.org/10.1016/j.psym.2011.02.007
# https://openalex.org/W1955235752           https://doi.org/10.3389/fphar.2015.00258
# https://openalex.org/W2373924009                  https://doi.org/10.1159/000446159
# https://openalex.org/W1997922550                  https://doi.org/10.1002/mds.20700
#
#                                                                               title  \
# openalex_id
# https://openalex.org/W2478209357  Aetiology of in-hospital cardiac arrest on gen...
# https://openalex.org/W2095179087  Linking Electronic Health Record-Extracted Psy...
# https://openalex.org/W1955235752  HDL and glucose metabolism: current evidence a...
# https://openalex.org/W2373924009  Reduced Cardiovascular Mortality Associated wi...
# https://openalex.org/W1997922550  Long-term benefits of rivastigmine in dementia...
#
#                                                                            abstract  \
# openalex_id
# https://openalex.org/W2478209357  Aetiology of in-hospital cardiac arrests (IHCA...
# https://openalex.org/W2095179087  Background Knowledge of psychosocial character...
# https://openalex.org/W1955235752  High-density lipoprotein (HDL) and its princip...
# https://openalex.org/W2373924009  &lt;b&gt;&lt;i&gt;Background:&lt;/i&gt;&lt;/b&...
# https://openalex.org/W1997922550  In patients with dementia associated with Park...
#
#                                   label_included
# openalex_id
# https://openalex.org/W2478209357               0
# https://openalex.org/W2095179087               0
# https://openalex.org/W1955235752               0
# https://openalex.org/W2373924009               0
# https://openalex.org/W1997922550               0

# %% [markdown]
# ## Get each dataset as dict

# %%
for d in iter_datasets():

    obj = d.to_dict()

    print(d.name, type(obj))
# Out:
# Appenzeller-Herzog_2019 <class 'dict'>
# Bos_2018 <class 'dict'>
# Brouwer_2019 <class 'dict'>
# Chou_2003 <class 'dict'>
# Chou_2004 <class 'dict'>
# Donners_2021 <class 'dict'>
# Hall_2012 <class 'dict'>
# Jeyaraman_2020 <class 'dict'>
# Leenaars_2019 <class 'dict'>
# Leenaars_2020 <class 'dict'>
# Meijboom_2021 <class 'dict'>
# Menon_2022 <class 'dict'>
# Moran_2021 <class 'dict'>
# Muthu_2021 <class 'dict'>
# Nelson_2002 <class 'dict'>
# Oud_2018 <class 'dict'>
# Radjenovic_2013 <class 'dict'>
# Sep_2021 <class 'dict'>
# Smid_2020 <class 'dict'>
# van_de_Schoot_2018 <class 'dict'>
# van_der_Valk_2021 <class 'dict'>
# van_der_Waal_2022 <class 'dict'>
# van_Dis_2020 <class 'dict'>
# Walker_2018 <class 'dict'>
# Wassenaar_2017 <class 'dict'>
# Wolters_2018 <class 'dict'>

# %%
pprint(list(obj.values())[0])
# Out:
# {'abstract': 'Aetiology of in-hospital cardiac arrests (IHCAs) on general '
#              'wards has not been studied. We aimed to determine the underlying '
#              'causes for IHCAs by the means of autopsy records and clinical '
#              'judgement of the treating consultants. Furthermore, we '
#              'investigated whether aetiology and preceding vital dysfunctions '
#              'are associated with long-term survival.Prospective observational '
#              'study between 2009-2011 including 279 adult IHCA patients '
#              'attended by medical emergency team in a Finnish university '
#              "hospital's general wards.The median age of the patients was 72 "
#              '(64, 80) years, 185 (66%) were male, 178 (64%) of events were '
#              'monitored/witnessed, first rhythm was shockable in 42 (15%) '
#              'cases and 53 (19%) patients survived six months. Aetiology was '
#              'determined as cardiac in 141 events, 73 of which were due to '
#              'acute myocardial infarction. There were 138 non-cardiac IHCAs; '
#              'most common causes were pneumonia (39) and exsanguination (16). '
#              'No statistical difference was observed in the incidence of '
#              'objective vital dysfunctions preceding the event between the '
#              'cardiac and non-cardiac groups (40% vs. 44%, p=0.448). '
#              'Subjective antecedents were more common in the cardiac cohort '
#              '(47% vs. 32%, p=0.022), chest pain being an example (11% vs. '
#              '0.7%, p<0.001). Reviewing all 279 IHCAs, only shockable primary '
#              'rhythm, monitored/witnessed event and low comorbidity score were '
#              'independently associated with 180-day survival.Cardiac aetiology '
#              'underlies half of the IHCAs on general wards. Both objective and '
#              'subjective antecedents are common. However, neither the cardiac '
#              'aetiology nor the absence of preceding deterioration of vital '
#              'signs were factors independently associated with a favourable '
#              'outcome.',
#  'doi': 'https://doi.org/10.1016/j.resuscitation.2016.07.007',
#  'label_included': 0,
#  'title': 'Aetiology of in-hospital cardiac arrest on general wards'}

# %% [markdown]
# ## Get single dataset

# %%
d = Dataset("Hall_2012")

d.to_frame()
# Out:
#                                                                             doi  \
# openalex_id
# https://openalex.org/W2131536587    https://doi.org/10.1109/indcon.2010.5712716
# https://openalex.org/W2557025555  https://doi.org/10.1109/induscon.2010.5740045
# https://openalex.org/W2143148279      https://doi.org/10.1109/tpwrd.2005.848672
# https://openalex.org/W2111816457  https://doi.org/10.1109/icelmach.2008.4799852
# https://openalex.org/W3142547111     https://doi.org/10.1109/ipdps.2006.1639408
# ...                                                                         ...
# https://openalex.org/W1974230717       https://doi.org/10.1049/iet-cdt:20070118
# https://openalex.org/W2572727817        https://doi.org/10.1109/tia.2003.811784
# https://openalex.org/W2107635292            https://doi.org/10.1109/dsn.2007.99
# https://openalex.org/W1954533418    https://doi.org/10.1109/iwvdvt.2005.1504633
# https://openalex.org/W1835572177      https://doi.org/10.1109/rams.2003.1182029
#
#                                                                               title  \
# openalex_id
# https://openalex.org/W2131536587  Computer vision based offset error computation...
# https://openalex.org/W2557025555  Design and development of a software for fault...
# https://openalex.org/W2143148279  Analytical Approach to Internal Fault Simulati...
# https://openalex.org/W2111816457  Nonlinear equivalent circuit model of a tracti...
# https://openalex.org/W3142547111                Fault tolerance with real-time Java
# ...                                                                             ...
# https://openalex.org/W1974230717  Self-routing, reconfigurable and fault-toleran...
# https://openalex.org/W2572727817  Stator winding turn-fault detection for closed...
# https://openalex.org/W2107635292  Using Register Lifetime Predictions to Protect...
# https://openalex.org/W1954533418  An early warning model for risk management of ...
# https://openalex.org/W1835572177  Investigating no fault found in the aerospace ...
#
#                                                                            abstract  \
# openalex_id
# https://openalex.org/W2131536587  The use of computer vision based approach has ...
# https://openalex.org/W2557025555  This paper presents an on-line fault diagnosis...
# https://openalex.org/W2143148279  A new method for simulating faulted transforme...
# https://openalex.org/W2111816457  The paper presents the development of an equiv...
# https://openalex.org/W3142547111  After having drawn up a state of the art on th...
# ...                                                                             ...
# https://openalex.org/W1974230717  Many examples of reconfigurable fault-tolerant...
# https://openalex.org/W2572727817  Sensorless diagnostics for line-connected mach...
# https://openalex.org/W2107635292  To increase the resistance of register files t...
# https://openalex.org/W1954533418  This paper has carried on the tentative discus...
# https://openalex.org/W1835572177  This paper describes a package of work to inve...
#
#                                   label_included
# openalex_id
# https://openalex.org/W2131536587               0
# https://openalex.org/W2557025555               0
# https://openalex.org/W2143148279               0
# https://openalex.org/W2111816457               0
# https://openalex.org/W3142547111               0
# ...                                          ...
# https://openalex.org/W1974230717               0
# https://openalex.org/W2572727817               0
# https://openalex.org/W2107635292               0
# https://openalex.org/W1954533418               0
# https://openalex.org/W1835572177               0
#
# [8793 rows x 4 columns]

# %% [markdown]
# ## Get other variables than title and abstract

# %%
d = Dataset("Hall_2012")

obj = d.to_dict(["title", "referenced_works"])

pprint(list(obj.values())[0])
# Out:
# {'label_included': 0,
#  'referenced_works': ['https://openalex.org/W68154617',
#                       'https://openalex.org/W96697480',
#                       'https://openalex.org/W1985243637',
#                       'https://openalex.org/W2041367003',
#                       'https://openalex.org/W2100368227',
#                       'https://openalex.org/W2125186487',
#                       'https://openalex.org/W2220315489',
#                       'https://openalex.org/W2276549114',
#                       'https://openalex.org/W2540405531'],
#  'title': 'Computer vision based offset error computation for web printing '
#           'machines using FPGA'}

# %% [markdown]
# ## Get metadata about the final publication

# %%
d = Dataset("Hall_2012")

# the full OpenAlex work
d.metadata
# Out:
# {'key': 'Hall_2012',
#  'collection': {'id': 'https://openalex.org/W2785836523',
#   'doi': 'https://doi.org/10.1007/s10664-017-9587-0',
#   'title': 'Finding better active learners for faster literature reviews',
#   'display_name': 'Finding better active learners for faster literature reviews',
#   'publication_year': 2016,
#   'publication_date': '2016-12-10',
#   'ids': {'openalex': 'https://openalex.org/W2785836523',
#    'doi': 'https://doi.org/10.1007/s10664-017-9587-0',
#    'mag': '2785836523'},
#   'primary_location': {'is_oa': False,
#    'landing_page_url': 'https://doi.org/10.1007/s10664-017-9587-0',
#    'pdf_url': None,
#    'source': {'id': 'https://openalex.org/S109852484',
#     'display_name': 'Empirical Software Engineering',
#     'issn_l': '1382-3256',
#     'issn': ['1382-3256', '1573-7616'],
#     'host_organization': 'https://openalex.org/P4310319900',
#     'host_organization_name': 'Springer Science+Business Media',
#     'type': 'journal'},
#    'license': None,
#    'version': None},
#   'host_venue': {'id': 'https://openalex.org/S109852484',
#    'issn_l': '1382-3256',
#    'issn': ['1382-3256', '1573-7616'],
#    'display_name': 'Empirical Software Engineering',
#    'publisher': 'Springer Science+Business Media',
#    'type': 'journal',
#    'url': None,
#    'is_oa': False,
#    'version': None,
#    'license': None},
#   'type': 'journal-article',
#   'open_access': {'is_oa': True,
#    'oa_status': 'green',
#    'oa_url': 'http://arxiv.org/pdf/1612.03224',
#    'any_repository_has_fulltext': True},
#   'authorships': [{'author_position': 'first',
#     'author': {'id': 'https://openalex.org/A4354258825',
#      'display_name': 'Zhe Yu',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I137902535',
#       'display_name': 'North Carolina State University',
#       'ror': 'https://ror.org/04tj63d06',
#       'country_code': 'US',
#       'type': 'education'}],
#     'is_corresponding': False,
#     'raw_affiliation_string': 'North Carolina State University ,'},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A2138713435',
#      'display_name': 'Nicholas A. Kraft',
#      'orcid': 'https://orcid.org/0000-0002-7960-766X'},
#     'institutions': [{'id': 'https://openalex.org/I885143765',
#       'display_name': 'ABB',
#       'ror': 'https://ror.org/00ks5vt51',
#       'country_code': 'CH',
#       'type': 'company'}],
#     'is_corresponding': False,
#     'raw_affiliation_string': 'ABB Corporate Research'},
#    {'author_position': 'last',
#     'author': {'id': 'https://openalex.org/A4356224073',
#      'display_name': 'Tim Menzies',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I137902535',
#       'display_name': 'North Carolina State University',
#       'ror': 'https://ror.org/04tj63d06',
#       'country_code': 'US',
#       'type': 'education'}],
#     'is_corresponding': False,
#     'raw_affiliation_string': 'North Carolina State University ,'}],
#   'cited_by_count': 34,
#   'biblio': {'volume': '23',
#    'issue': '6',
#    'first_page': '3161',
#    'last_page': '3186'},
#   'is_retracted': False,
#   'is_paratext': False,
#   'concepts': [{'id': 'https://openalex.org/C152752567',
#     'wikidata': 'https://www.wikidata.org/wiki/Q116877',
#     'display_name': 'Code refactoring',
#     'level': 3,
#     'score': '0.68280923'},
#    {'id': 'https://openalex.org/C41008148',
#     'wikidata': 'https://www.wikidata.org/wiki/Q21198',
#     'display_name': 'Computer science',
#     'level': 0,
#     'score': '0.6495098'},
#    {'id': 'https://openalex.org/C2777922441',
#     'wikidata': 'https://www.wikidata.org/wiki/Q3535655',
#     'display_name': 'Cataloging',
#     'level': 2,
#     'score': '0.5848849'},
#    {'id': 'https://openalex.org/C189708586',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1504425',
#     'display_name': 'Systematic review',
#     'level': 3,
#     'score': '0.5461054'},
#    {'id': 'https://openalex.org/C23123220',
#     'wikidata': 'https://www.wikidata.org/wiki/Q816826',
#     'display_name': 'Information retrieval',
#     'level': 1,
#     'score': '0.45707944'},
#    {'id': 'https://openalex.org/C2522767166',
#     'wikidata': 'https://www.wikidata.org/wiki/Q2374463',
#     'display_name': 'Data science',
#     'level': 1,
#     'score': '0.4546436'},
#    {'id': 'https://openalex.org/C3018574109',
#     'wikidata': 'https://www.wikidata.org/wiki/Q329338',
#     'display_name': 'State of art',
#     'level': 2,
#     'score': '0.45279184'},
#    {'id': 'https://openalex.org/C154945302',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11660',
#     'display_name': 'Artificial intelligence',
#     'level': 1,
#     'score': '0.33550307'},
#    {'id': 'https://openalex.org/C136764020',
#     'wikidata': 'https://www.wikidata.org/wiki/Q466',
#     'display_name': 'World Wide Web',
#     'level': 1,
#     'score': '0.28199726'},
#    {'id': 'https://openalex.org/C2777904410',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7397',
#     'display_name': 'Software',
#     'level': 2,
#     'score': '0.10522559'},
#    {'id': 'https://openalex.org/C2779473830',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1540899',
#     'display_name': 'MEDLINE',
#     'level': 2,
#     'score': '0.10103059'},
#    {'id': 'https://openalex.org/C199360897',
#     'wikidata': 'https://www.wikidata.org/wiki/Q9143',
#     'display_name': 'Programming language',
#     'level': 1,
#     'score': '0.09589484'},
#    {'id': 'https://openalex.org/C17744445',
#     'wikidata': 'https://www.wikidata.org/wiki/Q36442',
#     'display_name': 'Political science',
#     'level': 0,
#     'score': '0.0'},
#    {'id': 'https://openalex.org/C199539241',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7748',
#     'display_name': 'Law',
#     'level': 1,
#     'score': '0.0'}],
#   'mesh': [],
#   'locations': [{'is_oa': False,
#     'landing_page_url': 'https://doi.org/10.1007/s10664-017-9587-0',
#     'pdf_url': None,
#     'source': {'id': 'https://openalex.org/S109852484',
#      'display_name': 'Empirical Software Engineering',
#      'issn_l': '1382-3256',
#      'issn': ['1382-3256', '1573-7616'],
#      'host_organization': 'https://openalex.org/P4310319900',
#      'host_organization_name': 'Springer Science+Business Media',
#      'type': 'journal'},
#     'license': None,
#     'version': None},
#    {'is_oa': True,
#     'landing_page_url': 'http://arxiv.org/abs/1612.03224',
#     'pdf_url': 'http://arxiv.org/pdf/1612.03224',
#     'source': {'id': 'https://openalex.org/S4306400194',
#      'display_name': 'arXiv (Cornell University)',
#      'issn_l': None,
#      'issn': None,
#      'host_organization': 'https://openalex.org/I205783295',
#      'host_organization_name': 'Cornell University',
#      'type': 'repository'},
#     'license': None,
#     'version': 'submittedVersion'}],
#   'best_oa_location': {'is_oa': True,
#    'landing_page_url': 'http://arxiv.org/abs/1612.03224',
#    'pdf_url': 'http://arxiv.org/pdf/1612.03224',
#    'source': {'id': 'https://openalex.org/S4306400194',
#     'display_name': 'arXiv (Cornell University)',
#     'issn_l': None,
#     'issn': None,
#     'host_organization': 'https://openalex.org/I205783295',
#     'host_organization_name': 'Cornell University',
#     'type': 'repository'},
#    'license': None,
#    'version': 'submittedVersion'},
#   'alternate_host_venues': [{'id': 'https://openalex.org/S109852484',
#     'display_name': 'Empirical Software Engineering',
#     'type': 'journal',
#     'url': None,
#     'is_oa': False,
#     'version': None,
#     'license': None},
#    {'id': 'https://openalex.org/S4306400194',
#     'display_name': 'arXiv (Cornell University)',
#     'type': 'repository',
#     'url': 'http://arxiv.org/pdf/1612.03224',
#     'is_oa': True,
#     'version': 'submittedVersion',
#     'license': None}],
#   'referenced_works': ['https://openalex.org/W168362576',
#    'https://openalex.org/W198074091',
#    'https://openalex.org/W1973251307',
#    'https://openalex.org/W1975675278',
#    'https://openalex.org/W1977717877',
#    'https://openalex.org/W1986251315',
#    'https://openalex.org/W2008365184',
#    'https://openalex.org/W2019955851',
#    'https://openalex.org/W2021285462',
#    'https://openalex.org/W2022645200',
#    'https://openalex.org/W2025274780',
#    'https://openalex.org/W2027864297',
#    'https://openalex.org/W2029075138',
#    'https://openalex.org/W2035720976',
#    'https://openalex.org/W2037771830',
#    'https://openalex.org/W2043566294',
#    'https://openalex.org/W2043634247',
#    'https://openalex.org/W2044980364',
#    'https://openalex.org/W2049691306',
#    'https://openalex.org/W2071055029',
#    'https://openalex.org/W2078936286',
#    'https://openalex.org/W2099883114',
#    'https://openalex.org/W2100053037',
#    'https://openalex.org/W2113035899',
#    'https://openalex.org/W2124493593',
#    'https://openalex.org/W2133933998',
#    'https://openalex.org/W2138118601',
#    'https://openalex.org/W2144326572',
#    'https://openalex.org/W2147469877',
#    'https://openalex.org/W2151666086',
#    'https://openalex.org/W2160988203',
#    'https://openalex.org/W2162411541',
#    'https://openalex.org/W2168130919',
#    'https://openalex.org/W2196942307',
#    'https://openalex.org/W2344072768',
#    'https://openalex.org/W2374823395',
#    'https://openalex.org/W2400753773',
#    'https://openalex.org/W2404140835',
#    'https://openalex.org/W2404374285',
#    'https://openalex.org/W2406978180',
#    'https://openalex.org/W2512040454',
#    'https://openalex.org/W2522451690',
#    'https://openalex.org/W2551680670',
#    'https://openalex.org/W2560438049',
#    'https://openalex.org/W2621485502',
#    'https://openalex.org/W2735984040',
#    'https://openalex.org/W4206723194',
#    'https://openalex.org/W4247781538'],
#   'related_works': ['https://openalex.org/W21169582',
#    'https://openalex.org/W1577157553',
#    'https://openalex.org/W2144190808',
#    'https://openalex.org/W2356555785',
#    'https://openalex.org/W2384888906',
#    'https://openalex.org/W2557652470',
#    'https://openalex.org/W2562567887',
#    'https://openalex.org/W2785836523',
#    'https://openalex.org/W2973167930',
#    'https://openalex.org/W3177311804'],
#   'ngrams_url': 'https://api.openalex.org/works/W2785836523/ngrams',
#   'abstract_inverted_index': {'Literature': [0],
#    'reviews': [1, 52, 85],
#    'can': [2],
#    'be': [3],
#    'time-consuming': [4],
#    'and': [5, 11, 21, 28],
#    'tedious': [6],
#    'to': [7, 60, 79],
#    'complete.': [8],
#    'By': [9],
#    'cataloging': [10],
#    'refactoring': [12],
#    'three': [13],
#    'state-of-the-art': [14, 81],
#    'active': [15],
#    'learning': [16],
#    'techniques': [17],
#    'from': [18, 48],
#    'evidence-based': [19],
#    'medicine': [20],
#    'legal': [22],
#    'electronic': [23],
#    'discovery,': [24],
#    'this': [25],
#    'paper': [26, 42],
#    'finds': [27],
#    'implements': [29],
#    'FASTREAD,': [30],
#    'a': [31, 36, 98],
#    'faster': [32],
#    'technique': [33],
#    'for': [34],
#    'studying': [35],
#    'large': [37],
#    'corpus': [38],
#    'of': [39, 74, 93],
#    'documents.': [40],
#    'This': [41],
#    'assesses': [43],
#    'FASTREAD': [44, 63, 84],
#    'using': [45],
#    'datasets': [46],
#    'generated': [47],
#    'existing': [49],
#    'SE': [50],
#    'literature': [51, 100],
#    '(Hall,': [53],
#    'Wahono,': [54],
#    "Radjenovi\\'c,": [55],
#    'Kitchenham': [56],
#    'et': [57],
#    'al.).': [58],
#    'Compared': [59, 78],
#    'manual': [61],
#    'methods,': [62, 83],
#    'lets': [64],
#    'researchers': [65],
#    'find': [66],
#    '95%': [67],
#    'relevant': [68, 94],
#    'studies': [69, 88, 96],
#    'after': [70],
#    'reviewing': [71],
#    'an': [72],
#    'order': [73],
#    'magnitude': [75],
#    'fewer': [76, 87],
#    'papers.': [77],
#    'other': [80],
#    'automatic': [82],
#    '20-50%': [86],
#    'while': [89],
#    'finding': [90],
#    'same': [91],
#    'number': [92],
#    'primary': [95],
#    'in': [97],
#    'systematic': [99],
#    'review.': [101]},
#   'cited_by_api_url': 'https://api.openalex.org/works?filter=cites:W2785836523',
#   'counts_by_year': [{'year': 2023, 'cited_by_count': 2},
#    {'year': 2022, 'cited_by_count': 11},
#    {'year': 2021, 'cited_by_count': 9},
#    {'year': 2020, 'cited_by_count': 6},
#    {'year': 2019, 'cited_by_count': 4},
#    {'year': 2017, 'cited_by_count': 2}],
#   'updated_date': '2023-04-10T06:48:45.466053',
#   'created_date': '2018-02-23'},
#  'publication': {'id': 'https://openalex.org/W2151666086',
#   'doi': 'https://doi.org/10.1109/tse.2011.103',
#   'title': 'A Systematic Literature Review on Fault Prediction Performance in Software Engineering',
#   'display_name': 'A Systematic Literature Review on Fault Prediction Performance in Software Engineering',
#   'publication_year': 2012,
#   'publication_date': '2012-11-01',
#   'ids': {'openalex': 'https://openalex.org/W2151666086',
#    'doi': 'https://doi.org/10.1109/tse.2011.103',
#    'mag': '2151666086'},
#   'primary_location': {'is_oa': False,
#    'landing_page_url': 'https://doi.org/10.1109/tse.2011.103',
#    'pdf_url': None,
#    'source': {'id': 'https://openalex.org/S8351582',
#     'display_name': 'IEEE Transactions on Software Engineering',
#     'issn_l': '0098-5589',
#     'issn': ['0098-5589', '1939-3520', '2326-3881'],
#     'host_organization': 'https://openalex.org/P4310320439',
#     'host_organization_name': 'IEEE Computer Society',
#     'type': 'journal'},
#    'license': None,
#    'version': None},
#   'host_venue': {'id': 'https://openalex.org/S8351582',
#    'issn_l': '0098-5589',
#    'issn': ['0098-5589', '1939-3520', '2326-3881'],
#    'display_name': 'IEEE Transactions on Software Engineering',
#    'publisher': 'IEEE Computer Society',
#    'type': 'journal',
#    'url': None,
#    'is_oa': False,
#    'version': None,
#    'license': None},
#   'type': 'journal-article',
#   'open_access': {'is_oa': True,
#    'oa_status': 'green',
#    'oa_url': 'https://researchrepository.ul.ie/articles/online_resource/A_Systematic_literature_review_on_fault_prediction_performance_in_software_engineering/19848790/1/files/35264761.pdf'},
#   'authorships': [{'author_position': 'first',
#     'author': {'id': 'https://openalex.org/A4358437630',
#      'display_name': 'Trevor J. Hall',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I59433898',
#       'display_name': 'Brunel University London',
#       'ror': 'https://ror.org/00dn4t376',
#       'country_code': 'GB',
#       'type': 'education'}],
#     'is_corresponding': False,
#     'raw_affiliation_string': 'Dept of Inf. Syst. & Comput., Brunel Univ., Uxbridge, UK'},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A4357049062',
#      'display_name': 'Simon Beecham',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I230495080',
#       'display_name': 'University of Limerick',
#       'ror': 'https://ror.org/00a0n9e72',
#       'country_code': 'IE',
#       'type': 'education'}],
#     'is_corresponding': False,
#     'raw_affiliation_string': 'LERO - The Irish Software Engineering Research Centre, University of Limerick, Limerick, Ireland'},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A4350018187',
#      'display_name': 'David Bowes',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I141584323',
#       'display_name': 'University of Hertfordshire',
#       'ror': 'https://ror.org/0267vjk41',
#       'country_code': 'GB',
#       'type': 'education'}],
#     'is_corresponding': False,
#     'raw_affiliation_string': 'Sci. & Technol. Res. Inst., Univ. of Hertfordshire, Hatfield, UK'},
#    {'author_position': 'middle',
#     'author': {'id': 'https://openalex.org/A2117642300',
#      'display_name': 'Derek W. R. Gray',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I141584323',
#       'display_name': 'University of Hertfordshire',
#       'ror': 'https://ror.org/0267vjk41',
#       'country_code': 'GB',
#       'type': 'education'}],
#     'is_corresponding': False,
#     'raw_affiliation_string': 'Sci. & Technol. Res. Inst., Univ. of Hertfordshire, Hatfield, UK'},
#    {'author_position': 'last',
#     'author': {'id': 'https://openalex.org/A4357993668',
#      'display_name': 'Serena J. Counsell',
#      'orcid': None},
#     'institutions': [{'id': 'https://openalex.org/I59433898',
#       'display_name': 'Brunel University London',
#       'ror': 'https://ror.org/00dn4t376',
#       'country_code': 'GB',
#       'type': 'education'}],
#     'is_corresponding': False,
#     'raw_affiliation_string': 'Dept of Inf. Syst. & Comput., Brunel Univ., Uxbridge, UK'}],
#   'cited_by_count': 832,
#   'biblio': {'volume': '38',
#    'issue': '6',
#    'first_page': '1276',
#    'last_page': '1304'},
#   'is_retracted': False,
#   'is_paratext': False,
#   'concepts': [{'id': 'https://openalex.org/C41008148',
#     'wikidata': 'https://www.wikidata.org/wiki/Q21198',
#     'display_name': 'Computer science',
#     'level': 0,
#     'score': '0.8312874'},
#    {'id': 'https://openalex.org/C45804977',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7239673',
#     'display_name': 'Predictive modelling',
#     'level': 2,
#     'score': '0.5951123'},
#    {'id': 'https://openalex.org/C117447612',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1412670',
#     'display_name': 'Software quality',
#     'level': 4,
#     'score': '0.57710904'},
#    {'id': 'https://openalex.org/C124101348',
#     'wikidata': 'https://www.wikidata.org/wiki/Q172491',
#     'display_name': 'Data mining',
#     'level': 1,
#     'score': '0.57546335'},
#    {'id': 'https://openalex.org/C2779343474',
#     'wikidata': 'https://www.wikidata.org/wiki/Q3109175',
#     'display_name': 'Context (archaeology)',
#     'level': 2,
#     'score': '0.56149685'},
#    {'id': 'https://openalex.org/C119857082',
#     'wikidata': 'https://www.wikidata.org/wiki/Q2539',
#     'display_name': 'Machine learning',
#     'level': 1,
#     'score': '0.54447806'},
#    {'id': 'https://openalex.org/C148483581',
#     'wikidata': 'https://www.wikidata.org/wiki/Q446488',
#     'display_name': 'Feature selection',
#     'level': 2,
#     'score': '0.531127'},
#    {'id': 'https://openalex.org/C151956035',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1132755',
#     'display_name': 'Logistic regression',
#     'level': 2,
#     'score': '0.4728299'},
#    {'id': 'https://openalex.org/C177264268',
#     'wikidata': 'https://www.wikidata.org/wiki/Q1514741',
#     'display_name': 'Set (abstract data type)',
#     'level': 2,
#     'score': '0.43372405'},
#    {'id': 'https://openalex.org/C52001869',
#     'wikidata': 'https://www.wikidata.org/wiki/Q812530',
#     'display_name': 'Naive Bayes classifier',
#     'level': 3,
#     'score': '0.42497286'},
#    {'id': 'https://openalex.org/C200601418',
#     'wikidata': 'https://www.wikidata.org/wiki/Q2193887',
#     'display_name': 'Reliability engineering',
#     'level': 1,
#     'score': '0.42298663'},
#    {'id': 'https://openalex.org/C2777904410',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7397',
#     'display_name': 'Software',
#     'level': 2,
#     'score': '0.42044693'},
#    {'id': 'https://openalex.org/C154945302',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11660',
#     'display_name': 'Artificial intelligence',
#     'level': 1,
#     'score': '0.3658086'},
#    {'id': 'https://openalex.org/C12267149',
#     'wikidata': 'https://www.wikidata.org/wiki/Q282453',
#     'display_name': 'Support vector machine',
#     'level': 2,
#     'score': '0.17897242'},
#    {'id': 'https://openalex.org/C529173508',
#     'wikidata': 'https://www.wikidata.org/wiki/Q638608',
#     'display_name': 'Software development',
#     'level': 3,
#     'score': '0.16897586'},
#    {'id': 'https://openalex.org/C127413603',
#     'wikidata': 'https://www.wikidata.org/wiki/Q11023',
#     'display_name': 'Engineering',
#     'level': 0,
#     'score': '0.085942656'},
#    {'id': 'https://openalex.org/C151730666',
#     'wikidata': 'https://www.wikidata.org/wiki/Q7205',
#     'display_name': 'Paleontology',
#     'level': 1,
#     'score': '0.0'},
#    {'id': 'https://openalex.org/C86803240',
#     'wikidata': 'https://www.wikidata.org/wiki/Q420',
#     'display_name': 'Biology',
#     'level': 0,
#     'score': '0.0'},
#    {'id': 'https://openalex.org/C199360897',
#     'wikidata': 'https://www.wikidata.org/wiki/Q9143',
#     'display_name': 'Programming language',
#     'level': 1,
#     'score': '0.0'}],
#   'mesh': [],
#   'locations': [{'is_oa': False,
#     'landing_page_url': 'https://doi.org/10.1109/tse.2011.103',
#     'pdf_url': None,
#     'source': {'id': 'https://openalex.org/S8351582',
#      'display_name': 'IEEE Transactions on Software Engineering',
#      'issn_l': '0098-5589',
#      'issn': ['0098-5589', '1939-3520', '2326-3881'],
#      'host_organization': 'https://openalex.org/P4310320439',
#      'host_organization_name': 'IEEE Computer Society',
#      'type': 'journal'},
#     'license': None,
#     'version': None},
#    {'is_oa': True,
#     'landing_page_url': 'http://hdl.handle.net/10344/1772',
#     'pdf_url': 'https://ulir.ul.ie/bitstream/10344/1772/2/2011_hall%20%28a%29.pdf',
#     'source': {'id': 'https://openalex.org/S4306400033',
#      'display_name': 'Arrow@dit (Dublin Institute of Technology)',
#      'issn_l': None,
#      'issn': None,
#      'host_organization': 'https://openalex.org/I115570527',
#      'host_organization_name': 'Dublin Institute of Technology',
#      'type': 'repository'},
#     'license': 'pd',
#     'version': 'publishedVersion'},
#    {'is_oa': True,
#     'landing_page_url': 'http://bura.brunel.ac.uk/handle/2438/5907',
#     'pdf_url': 'http://bura.brunel.ac.uk/bitstream/2438/5907/2/Fulltext.pdf',
#     'source': {'id': 'https://openalex.org/S4306401473',
#      'display_name': 'Brunel University Research Archive (BURA) (Brunel University London)',
#      'issn_l': None,
#      'issn': None,
#      'host_organization': 'https://openalex.org/I59433898',
#      'host_organization_name': 'Brunel University London',
#      'type': 'repository'},
#     'license': 'pd',
#     'version': 'submittedVersion'}],
#   'best_oa_location': {'is_oa': True,
#    'landing_page_url': 'http://hdl.handle.net/10344/1772',
#    'pdf_url': 'https://ulir.ul.ie/bitstream/10344/1772/2/2011_hall%20%28a%29.pdf',
#    'source': {'id': 'https://openalex.org/S4306400033',
#     'display_name': 'Arrow@dit (Dublin Institute of Technology)',
#     'issn_l': None,
#     'issn': None,
#     'host_organization': 'https://openalex.org/I115570527',
#     'host_organization_name': 'Dublin Institute of Technology',
#     'type': 'repository'},
#    'license': 'pd',
#    'version': 'publishedVersion'},
#   'alternate_host_venues': [{'id': 'https://openalex.org/S8351582',
#     'display_name': 'IEEE Transactions on Software Engineering',
#     'type': 'journal',
#     'url': None,
#     'is_oa': False,
#     'version': None,
#     'license': None},
#    {'id': 'https://openalex.org/S4306400033',
#     'display_name': 'Arrow@dit (Dublin Institute of Technology)',
#     'type': 'repository',
#     'url': 'https://ulir.ul.ie/bitstream/10344/1772/2/2011_hall%20%28a%29.pdf',
#     'is_oa': True,
#     'version': 'publishedVersion',
#     'license': 'pd'},
#    {'id': 'https://openalex.org/S4306401530',
#     'display_name': 'University of Limerick Institutional Repository (University of Limerick)',
#     'type': 'repository',
#     'url': 'https://researchrepository.ul.ie/articles/online_resource/A_Systematic_literature_review_on_fault_prediction_performance_in_software_engineering/19848790/1/files/35264761.pdf',
#     'is_oa': True,
#     'version': 'publishedVersion',
#     'license': 'cc-by-nc-sa'},
#    {'id': 'https://openalex.org/S4306401473',
#     'display_name': 'Brunel University Research Archive (BURA) (Brunel University London)',
#     'type': 'repository',
#     'url': 'http://bura.brunel.ac.uk/bitstream/2438/5907/2/Fulltext.pdf',
#     'is_oa': True,
#     'version': 'submittedVersion',
#     'license': 'pd'}],
#   'referenced_works': ['https://openalex.org/W1482971670',
#    'https://openalex.org/W1493788687',
#    'https://openalex.org/W1520427008',
#    'https://openalex.org/W1573396645',
#    'https://openalex.org/W1630929475',
#    'https://openalex.org/W1635138928',
#    'https://openalex.org/W1670613434',
#    'https://openalex.org/W1806390057',
#    'https://openalex.org/W1820030238',
#    'https://openalex.org/W1870939480',
#    'https://openalex.org/W1884377372',
#    'https://openalex.org/W1941659294',
#    'https://openalex.org/W1964062576',
#    'https://openalex.org/W1968150772',
#    'https://openalex.org/W1968652658',
#    'https://openalex.org/W1969319425',
#    'https://openalex.org/W1969646775',
#    'https://openalex.org/W1973306813',
#    'https://openalex.org/W1973540172',
#    'https://openalex.org/W1975040830',
#    'https://openalex.org/W1976526581',
#    'https://openalex.org/W1978014436',
#    'https://openalex.org/W1982220412',
#    'https://openalex.org/W1986453394',
#    'https://openalex.org/W1986683951',
#    'https://openalex.org/W1988510359',
#    'https://openalex.org/W1989664908',
#    'https://openalex.org/W1993220166',
#    'https://openalex.org/W1995029977',
#    'https://openalex.org/W1999519916',
#    'https://openalex.org/W2000251235',
#    'https://openalex.org/W2001203840',
#    'https://openalex.org/W2002242562',
#    'https://openalex.org/W2003885074',
#    'https://openalex.org/W2003934931',
#    'https://openalex.org/W2004619528',
#    'https://openalex.org/W2006658471',
#    'https://openalex.org/W2008085811',
#    'https://openalex.org/W2008230257',
#    'https://openalex.org/W2008871892',
#    'https://openalex.org/W2015910788',
#    'https://openalex.org/W2017439596',
#    'https://openalex.org/W2018828965',
#    'https://openalex.org/W2019338079',
#    'https://openalex.org/W2021235145',
#    'https://openalex.org/W2021509116',
#    'https://openalex.org/W2024650695',
#    'https://openalex.org/W2026312277',
#    'https://openalex.org/W2028840449',
#    'https://openalex.org/W2029853454',
#    'https://openalex.org/W2034259517',
#    'https://openalex.org/W2034445489',
#    'https://openalex.org/W2036296745',
#    'https://openalex.org/W2037002715',
#    'https://openalex.org/W2037316754',
#    'https://openalex.org/W2038464048',
#    'https://openalex.org/W2038979200',
#    'https://openalex.org/W2039081830',
#    'https://openalex.org/W2039785233',
#    'https://openalex.org/W2043387105',
#    'https://openalex.org/W2046671629',
#    'https://openalex.org/W2046830558',
#    'https://openalex.org/W2049831820',
#    'https://openalex.org/W2051518864',
#    'https://openalex.org/W2051978688',
#    'https://openalex.org/W2053679663',
#    'https://openalex.org/W2053724458',
#    'https://openalex.org/W2055784794',
#    'https://openalex.org/W2057780988',
#    'https://openalex.org/W2058698726',
#    'https://openalex.org/W2063719920',
#    'https://openalex.org/W2066325414',
#    'https://openalex.org/W2066610500',
#    'https://openalex.org/W2072785870',
#    'https://openalex.org/W2073767361',
#    'https://openalex.org/W2080066761',
#    'https://openalex.org/W2082314767',
#    'https://openalex.org/W2083221797',
#    'https://openalex.org/W2093995814',
#    'https://openalex.org/W2097044443',
#    'https://openalex.org/W2097840435',
#    'https://openalex.org/W2098340665',
#    'https://openalex.org/W2100034782',
#    'https://openalex.org/W2100270576',
#    'https://openalex.org/W2100959900',
#    'https://openalex.org/W2101227285',
#    'https://openalex.org/W2101728371',
#    'https://openalex.org/W2101819268',
#    'https://openalex.org/W2102193394',
#    'https://openalex.org/W2103458796',
#    'https://openalex.org/W2103715428',
#    'https://openalex.org/W2104124430',
#    'https://openalex.org/W2104882279',
#    'https://openalex.org/W2105300539',
#    'https://openalex.org/W2105776892',
#    'https://openalex.org/W2106423417',
#    'https://openalex.org/W2107323945',
#    'https://openalex.org/W2107406649',
#    'https://openalex.org/W2108610041',
#    'https://openalex.org/W2109571910',
#    'https://openalex.org/W2110431240',
#    'https://openalex.org/W2111517663',
#    'https://openalex.org/W2112658968',
#    'https://openalex.org/W2114124859',
#    'https://openalex.org/W2114191341',
#    'https://openalex.org/W2114363693',
#    'https://openalex.org/W2116110050',
#    'https://openalex.org/W2116173875',
#    'https://openalex.org/W2117593603',
#    'https://openalex.org/W2119016061',
#    'https://openalex.org/W2120484483',
#    'https://openalex.org/W2120738100',
#    'https://openalex.org/W2120999344',
#    'https://openalex.org/W2121835830',
#    'https://openalex.org/W2122696684',
#    'https://openalex.org/W2122839350',
#    'https://openalex.org/W2123279272',
#    'https://openalex.org/W2123551785',
#    'https://openalex.org/W2123675623',
#    'https://openalex.org/W2124545752',
#    'https://openalex.org/W2124618155',
#    'https://openalex.org/W2125036506',
#    'https://openalex.org/W2125343911',
#    'https://openalex.org/W2125951552',
#    'https://openalex.org/W2125999269',
#    'https://openalex.org/W2126166995',
#    'https://openalex.org/W2126626812',
#    'https://openalex.org/W2127929486',
#    'https://openalex.org/W2128233336',
#    'https://openalex.org/W2128666163',
#    'https://openalex.org/W2129857650',
#    'https://openalex.org/W2130883460',
#    'https://openalex.org/W2130898128',
#    'https://openalex.org/W2131712385',
#    'https://openalex.org/W2132887549',
#    'https://openalex.org/W2133894309',
#    'https://openalex.org/W2135198476',
#    'https://openalex.org/W2135250985',
#    'https://openalex.org/W2135370021',
#    'https://openalex.org/W2135989251',
#    'https://openalex.org/W2136047917',
#    'https://openalex.org/W2136137167',
#    'https://openalex.org/W2136234086',
#    'https://openalex.org/W2137235241',
#    'https://openalex.org/W2137367944',
#    'https://openalex.org/W2138154779',
#    'https://openalex.org/W2138517458',
#    'https://openalex.org/W2138827327',
#    'https://openalex.org/W2139749383',
#    'https://openalex.org/W2140117423',
#    'https://openalex.org/W2141051748',
#    'https://openalex.org/W2141482658',
#    'https://openalex.org/W2142481192',
#    'https://openalex.org/W2143085507',
#    'https://openalex.org/W2143174846',
#    'https://openalex.org/W2143189463',
#    'https://openalex.org/W2143637886',
#    'https://openalex.org/W2143746453',
#    'https://openalex.org/W2143878618',
#    'https://openalex.org/W2144177913',
#    'https://openalex.org/W2146474553',
#    'https://openalex.org/W2146752379',
#    'https://openalex.org/W2146947654',
#    'https://openalex.org/W2147105902',
#    'https://openalex.org/W2148068009',
#    'https://openalex.org/W2149014999',
#    'https://openalex.org/W2149586027',
#    'https://openalex.org/W2150361830',
#    'https://openalex.org/W2150472843',
#    'https://openalex.org/W2150786161',
#    'https://openalex.org/W2151553346',
#    'https://openalex.org/W2152408529',
#    'https://openalex.org/W2153627807',
#    'https://openalex.org/W2153863197',
#    'https://openalex.org/W2154343132',
#    'https://openalex.org/W2154446978',
#    'https://openalex.org/W2154816175',
#    'https://openalex.org/W2158333206',
#    'https://openalex.org/W2158561928',
#    'https://openalex.org/W2158744032',
#    'https://openalex.org/W2159610968',
#    'https://openalex.org/W2159662550',
#    'https://openalex.org/W2160274766',
#    'https://openalex.org/W2160928200',
#    'https://openalex.org/W2161470369',
#    'https://openalex.org/W2163590173',
#    'https://openalex.org/W2163732854',
#    'https://openalex.org/W2164636917',
#    'https://openalex.org/W2166692380',
#    'https://openalex.org/W2167846874',
#    'https://openalex.org/W2168079753',
#    'https://openalex.org/W2168483093',
#    'https://openalex.org/W2169721776',
#    'https://openalex.org/W2170186889',
#    'https://openalex.org/W2170866915',
#    'https://openalex.org/W2544013977',
#    'https://openalex.org/W2544961394',
#    'https://openalex.org/W2546195536',
#    'https://openalex.org/W3104516493',
#    'https://openalex.org/W3106318554',
#    'https://openalex.org/W3141989311',
#    'https://openalex.org/W3143822685',
#    'https://openalex.org/W3151987713',
#    'https://openalex.org/W4205170104',
#    'https://openalex.org/W4237979974',
#    'https://openalex.org/W4243127898',
#    'https://openalex.org/W4247369679',
#    'https://openalex.org/W4248521920',
#    'https://openalex.org/W4296394699'],
#   'related_works': ['https://openalex.org/W2901495210',
#    'https://openalex.org/W3004984807',
#    'https://openalex.org/W3045445851',
#    'https://openalex.org/W3105251098',
#    'https://openalex.org/W3132847290',
#    'https://openalex.org/W3160244858',
#    'https://openalex.org/W4212852473',
#    'https://openalex.org/W4220916329',
#    'https://openalex.org/W4226324856',
#    'https://openalex.org/W4295102877'],
#   'ngrams_url': 'https://api.openalex.org/works/W2151666086/ngrams',
#   'abstract_inverted_index': {'Background:': [0],
#    'The': [1, 96, 143],
#    'accurate': [2],
#    'prediction': [3, 48, 61, 163],
#    'of': [4, 24, 32, 46, 77, 117, 161],
#    'where': [5],
#    'faults': [6],
#    'are': [7, 138, 158, 172],
#    'likely': [8],
#    'to': [9, 57, 67, 88, 102, 133, 146, 150, 153],
#    'occur': [10],
#    'in': [11, 165],
#    'code': [12],
#    'can': [13],
#    'help': [14],
#    'direct': [15],
#    'test': [16],
#    'effort,': [17],
#    'reduce': [18],
#    'costs,': [19],
#    'and': [20, 38, 74, 84, 93, 179, 185],
#    'improve': [21],
#    'the': [22, 30, 34, 39, 44, 72, 89],
#    'quality': [23],
#    'software.': [25],
#    'Objective:': [26],
#    'We': [27, 51, 70],
#    'investigate': [28],
#    'how': [29],
#    'context': [31],
#    'models,': [33],
#    'independent': [35, 118],
#    'variables': [36, 119],
#    'used,': [37],
#    'modeling': [40, 107],
#    'techniques': [41, 108],
#    'applied': [42, 132],
#    'influence': [43],
#    'performance': [45, 186],
#    'fault': [47, 60, 162],
#    'models.': [49],
#    'Method:': [50],
#    'used': [52, 122, 145],
#    'a': [53, 159, 176],
#    'systematic': [54],
#    'literature': [55],
#    'review': [56],
#    'identify': [58],
#    '208': [59],
#    'studies': [62, 79, 164, 171],
#    'published': [63],
#    'from': [64],
#    'January': [65],
#    '2000': [66],
#    'December': [68],
#    '2010.': [69],
#    'synthesize': [71],
#    'quantitative': [73],
#    'qualitative': [75],
#    'results': [76],
#    '36': [78],
#    'which': [80, 166, 180],
#    'report': [81, 181],
#    'sufficient': [82],
#    'contextual': [83],
#    'methodological': [85],
#    'information': [86],
#    'according': [87],
#    'criteria': [90],
#    'we': [91],
#    'develop': [92],
#    'apply.': [94],
#    'Results:': [95],
#    'models': [97, 124, 137, 148],
#    'that': [98, 125, 174],
#    'perform': [99, 126],
#    'well': [100],
#    'tend': [101],
#    'be': [103, 151],
#    'based': [104],
#    'on': [105],
#    'simple': [106],
#    'such': [109],
#    'as': [110],
#    'Naive': [111],
#    'Bayes': [112],
#    'or': [113],
#    'Logistic': [114],
#    'Regression.': [115],
#    'Combinations': [116],
#    'have': [120],
#    'been': [121, 131],
#    'by': [123],
#    'well.': [127, 141],
#    'Feature': [128],
#    'selection': [129],
#    'has': [130],
#    'these': [134],
#    'combinations': [135],
#    'when': [136],
#    'performing': [139],
#    'particularly': [140],
#    'Conclusion:': [142],
#    'methodology': [144, 178],
#    'build': [147],
#    'seems': [149],
#    'influential': [152],
#    'predictive': [154],
#    'performance.': [155],
#    'Although': [156],
#    'there': [157],
#    'set': [160],
#    'confidence': [167],
#    'is': [168],
#    'possible,': [169],
#    'more': [170],
#    'needed': [173],
#    'use': [175],
#    'reliable': [177],
#    'their': [182],
#    'context,': [183],
#    'methodology,': [184],
#    'comprehensively.': [187]},
#   'cited_by_api_url': 'https://api.openalex.org/works?filter=cites:W2151666086',
#   'counts_by_year': [{'year': 2023, 'cited_by_count': 19},
#    {'year': 2022, 'cited_by_count': 76},
#    {'year': 2021, 'cited_by_count': 95},
#    {'year': 2020, 'cited_by_count': 112},
#    {'year': 2019, 'cited_by_count': 98},
#    {'year': 2018, 'cited_by_count': 95},
#    {'year': 2017, 'cited_by_count': 71},
#    {'year': 2016, 'cited_by_count': 90},
#    {'year': 2015, 'cited_by_count': 76},
#    {'year': 2014, 'cited_by_count': 51},
#    {'year': 2013, 'cited_by_count': 36},
#    {'year': 2012, 'cited_by_count': 12}],
#   'updated_date': '2023-04-03T22:48:53.916978',
#   'created_date': '2016-06-24'},
#  'data': {'doi': '10.5281/zenodo.1162952',
#   'n_records': 8793,
#   'n_records_included': 104,
#   'concepts': {'included': [{'id': 'https://openalex.org/C41008148',
#      'wikidata': 'https://www.wikidata.org/wiki/Q21198',
#      'display_name': 'Computer science',
#      'level': 0,
#      'score': 0.6947671}]}}}

# %% [markdown]
# ## Build one big dataset

# %%
import pandas as pd

pd.concat([d.to_frame() for d in iter_datasets()], axis=0)
# Out:
#                                                                                 doi  \
# openalex_id
# https://openalex.org/W2402226166                                               None
# https://openalex.org/W2416808666                                               None
# https://openalex.org/W2060266518      https://doi.org/10.1016/s1367-5931(03)00018-8
# https://openalex.org/W2412464989  https://doi.org/10.5694/j.1326-5377.1970.tb634...
# https://openalex.org/W66518910                                                 None
# ...                                                                             ...
# https://openalex.org/W1995096921       https://doi.org/10.1016/j.injury.2012.07.007
# https://openalex.org/W1504586396                                               None
# https://openalex.org/W2114922669           https://doi.org/10.1177/1076029615598222
# https://openalex.org/W1657669688   https://doi.org/10.1111/j.1553-2712.2010.00976.x
# https://openalex.org/W1994490975                  https://doi.org/10.1159/000093323
#
#                                                                               title  \
# openalex_id
# https://openalex.org/W2402226166              Clinical aspects of Wilson's disease.
# https://openalex.org/W2416808666  [Hepatic changes in the neurological form of W...
# https://openalex.org/W2060266518                                 Copper in medicine
# https://openalex.org/W2412464989  HEPATOLENTICULAR DEGENERATION (WILSON'S DISEAS...
# https://openalex.org/W66518910    [Lupus erythematosus due to penicillamine asso...
# ...                                                                             ...
# https://openalex.org/W1995096921  A kick in the shins: The financial impact of u...
# https://openalex.org/W1504586396      Use of aspirin in cardiovascular prophylaxis.
# https://openalex.org/W2114922669  Home Treatment of Deep Venous Thrombosis in th...
# https://openalex.org/W1657669688  Prior Statin Use Is Not Associated With Improv...
# https://openalex.org/W1994490975  A Case of Severe Dyspnea and an Unusual Bronch...
#
#                                                                            abstract  \
# openalex_id
# https://openalex.org/W2402226166                                               None
# https://openalex.org/W2416808666                                               None
# https://openalex.org/W2060266518  Copper has been found to be causative in sever...
# https://openalex.org/W2412464989                                               None
# https://openalex.org/W66518910                                                 None
# ...                                                                             ...
# https://openalex.org/W1995096921  Warfarin is increasingly prescribed in the eld...
# https://openalex.org/W1504586396  The value of prophylatic low-dose aspirin in p...
# https://openalex.org/W2114922669  This is a retrospective cohort study of adults...
# https://openalex.org/W1657669688  The objective was to determine whether prior s...
# https://openalex.org/W1994490975                                               None
#
#                                   label_included
# openalex_id
# https://openalex.org/W2402226166               0
# https://openalex.org/W2416808666               0
# https://openalex.org/W2060266518               0
# https://openalex.org/W2412464989               0
# https://openalex.org/W66518910                 0
# ...                                          ...
# https://openalex.org/W1995096921               0
# https://openalex.org/W1504586396               0
# https://openalex.org/W2114922669               0
# https://openalex.org/W1657669688               0
# https://openalex.org/W1994490975               0
#
# [169288 rows x 4 columns]

# %% [markdown]
# ## Get work identifiers
#
# https://docs.openalex.org/api-entities/works/work-object#ids

# %%
d = Dataset("Appenzeller-Herzog_2019")
d.to_dict(["ids"])
# Out:
# {'https://openalex.org/W2402226166': {'ids': {'openalex': 'https://openalex.org/W2402226166',
#    'mag': '2402226166',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/2239872'},
#   'label_included': 0},
#  'https://openalex.org/W2416808666': {'ids': {'openalex': 'https://openalex.org/W2416808666',
#    'mag': '2416808666',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/6081668'},
#   'label_included': 0},
#  'https://openalex.org/W2060266518': {'ids': {'openalex': 'https://openalex.org/W2060266518',
#    'doi': 'https://doi.org/10.1016/s1367-5931(03)00018-8',
#    'mag': '2060266518',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/12714053'},
#   'label_included': 0},
#  'https://openalex.org/W2412464989': {'ids': {'openalex': 'https://openalex.org/W2412464989',
#    'doi': 'https://doi.org/10.5694/j.1326-5377.1970.tb63427.x',
#    'mag': '2412464989',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/5494103'},
#   'label_included': 0},
#  'https://openalex.org/W66518910': {'ids': {'openalex': 'https://openalex.org/W66518910',
#    'mag': '66518910',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/5579428'},
#   'label_included': 0},
#  'https://openalex.org/W2465739237': {'ids': {'openalex': 'https://openalex.org/W2465739237',
#    'mag': '2465739237',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/6196633'},
#   'label_included': 0},
#  'https://openalex.org/W2063776599': {'ids': {'openalex': 'https://openalex.org/W2063776599',
#    'doi': 'https://doi.org/10.1016/0301-2115(95)02159-5',
#    'mag': '2063776599',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/7493698'},
#   'label_included': 0},
#  'https://openalex.org/W1985329347': {'ids': {'openalex': 'https://openalex.org/W1985329347',
#    'doi': 'https://doi.org/10.1016/s0162-0134(01)00376-2',
#    'mag': '1985329347',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/11803037'},
#   'label_included': 0},
#  'https://openalex.org/W2472024384': {'ids': {'openalex': 'https://openalex.org/W2472024384',
#    'mag': '2472024384',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/4572368'},
#   'label_included': 0},
#  'https://openalex.org/W1909571703': {'ids': {'openalex': 'https://openalex.org/W1909571703',
#    'doi': 'https://doi.org/10.4103/2230-8210.104107',
#    'mag': '1909571703',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/23565442',
#    'pmcid': 'https://www.ncbi.nlm.nih.gov/pmc/articles/3603090'},
#   'label_included': 0},
#  'https://openalex.org/W2174281073': {'ids': {'openalex': 'https://openalex.org/W2174281073',
#    'doi': 'https://doi.org/10.1016/s0016-5085(76)80455-6',
#    'mag': '2174281073',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/950097'},
#   'label_included': 0},
#  'https://openalex.org/W2416255246': {'ids': {'openalex': 'https://openalex.org/W2416255246',
#    'mag': '2416255246',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/5745277'},
#   'label_included': 0},
#  'https://openalex.org/W2760547687': {'ids': {'openalex': 'https://openalex.org/W2760547687',
#    'doi': 'https://doi.org/10.3389/fneur.2017.00503',
#    'mag': '2760547687',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/28993754',
#    'pmcid': 'https://www.ncbi.nlm.nih.gov/pmc/articles/5622302'},
#   'label_included': 0},
#  'https://openalex.org/W1983418182': {'ids': {'openalex': 'https://openalex.org/W1983418182',
#    'doi': 'https://doi.org/10.1007/bf01391452',
#    'mag': '1983418182',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/7172963'},
#   'label_included': 0},
#  'https://openalex.org/W752247271': {'ids': {'openalex': 'https://openalex.org/W752247271',
#    'doi': 'https://doi.org/10.15403/jgld.2014.1121.242.wls',
#    'mag': '752247271',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/26114178'},
#   'label_included': 0},
#  'https://openalex.org/W1971651073': {'ids': {'openalex': 'https://openalex.org/W1971651073',
#    'doi': 'https://doi.org/10.1016/j.exger.2007.12.002',
#    'mag': '1971651073',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/18221847'},
#   'label_included': 0},
#  'https://openalex.org/W2161557797': {'ids': {'openalex': 'https://openalex.org/W2161557797',
#    'doi': 'https://doi.org/10.1111/j.1399-5618.2007.00531.x',
#    'mag': '2161557797',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/18402634'},
#   'label_included': 0},
#  'https://openalex.org/W2418791490': {'ids': {'openalex': 'https://openalex.org/W2418791490',
#    'mag': '2418791490',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/8244665'},
#   'label_included': 0},
#  'https://openalex.org/W2038005440': {'ids': {'openalex': 'https://openalex.org/W2038005440',
#    'doi': 'https://doi.org/10.1016/s0272-6386(86)80019-1',
#    'mag': '2038005440',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/3752071'},
#   'label_included': 0},
#  'https://openalex.org/W2082839816': {'ids': {'openalex': 'https://openalex.org/W2082839816',
#    'doi': 'https://doi.org/10.1016/j.pediatrneurol.2006.04.004',
#    'mag': '2082839816',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/16996405'},
#   'label_included': 0},
#  'https://openalex.org/W2412150970': {'ids': {'openalex': 'https://openalex.org/W2412150970',
#    'mag': '2412150970',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/14582469'},
#   'label_included': 0},
#  'https://openalex.org/W1978311450': {'ids': {'openalex': 'https://openalex.org/W1978311450',
#    'doi': 'https://doi.org/10.7326/0003-4819-101-1-144_3',
#    'mag': '1978311450',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/6732083'},
#   'label_included': 0},
#  'https://openalex.org/W2887469578': {'ids': {'openalex': 'https://openalex.org/W2887469578',
#    'doi': 'https://doi.org/10.1002/mdc3.12639',
#    'mag': '2887469578',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/30637271',
#    'pmcid': 'https://www.ncbi.nlm.nih.gov/pmc/articles/6207128'},
#   'label_included': 0},
#  'https://openalex.org/W2033425122': {'ids': {'openalex': 'https://openalex.org/W2033425122',
#    'doi': 'https://doi.org/10.1016/s0140-6736(60)90109-4',
#    'mag': '2033425122',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/13842679'},
#   'label_included': 0},
#  'https://openalex.org/W2401276746': {'ids': {'openalex': 'https://openalex.org/W2401276746',
#    'mag': '2401276746',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/8618573'},
#   'label_included': 0},
#  'https://openalex.org/W2077537967': {'ids': {'openalex': 'https://openalex.org/W2077537967',
#    'doi': 'https://doi.org/10.1016/0030-4220(81)90151-1',
#    'mag': '2077537967',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/6940079'},
#   'label_included': 0},
#  'https://openalex.org/W4254884731': {'ids': {'openalex': 'https://openalex.org/W4254884731',
#    'doi': 'https://doi.org/10.1007/s10072-015-2467-8',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/26758994'},
#   'label_included': 0},
#  'https://openalex.org/W2435799149': {'ids': {'openalex': 'https://openalex.org/W2435799149',
#    'mag': '2435799149',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/4622917'},
#   'label_included': 0},
#  'https://openalex.org/W4235438882': {'ids': {'openalex': 'https://openalex.org/W4235438882',
#    'doi': 'https://doi.org/10.1097/01.mpg.0000516381.25680.b4'},
#   'label_included': 0},
#  'https://openalex.org/W1970726833': {'ids': {'openalex': 'https://openalex.org/W1970726833',
#    'doi': 'https://doi.org/10.1016/j.cpradiol.2003.09.004',
#    'mag': '1970726833',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/14712200'},
#   'label_included': 0},
#  'https://openalex.org/W2105000706': {'ids': {'openalex': 'https://openalex.org/W2105000706',
#    'doi': 'https://doi.org/10.2337/diacare.28.1.15',
#    'mag': '2105000706',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/15616227'},
#   'label_included': 0},
#  'https://openalex.org/W2003271155': {'ids': {'openalex': 'https://openalex.org/W2003271155',
#    'doi': 'https://doi.org/10.1111/j.1399-0004.2007.00853.x',
#    'mag': '2003271155',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/17718866'},
#   'label_included': 0},
#  'https://openalex.org/W2241091078': {'ids': {'openalex': 'https://openalex.org/W2241091078',
#    'doi': 'https://doi.org/10.1177/039463200702000122',
#    'mag': '2241091078',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/17346443'},
#   'label_included': 0},
#  'https://openalex.org/W2016885452': {'ids': {'openalex': 'https://openalex.org/W2016885452',
#    'doi': 'https://doi.org/10.1016/j.ncl.2004.06.005',
#    'mag': '2016885452',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/15474767'},
#   'label_included': 0},
#  'https://openalex.org/W2066624072': {'ids': {'openalex': 'https://openalex.org/W2066624072',
#    'doi': 'https://doi.org/10.1007/s00381-013-2283-5',
#    'mag': '2066624072',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/24092421'},
#   'label_included': 0},
#  'https://openalex.org/W2404054367': {'ids': {'openalex': 'https://openalex.org/W2404054367',
#    'mag': '2404054367',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/5706607'},
#   'label_included': 0},
#  'https://openalex.org/W2416659335': {'ids': {'openalex': 'https://openalex.org/W2416659335',
#    'mag': '2416659335',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/20428734'},
#   'label_included': 0},
#  'https://openalex.org/W4242082702': {'ids': {'openalex': 'https://openalex.org/W4242082702',
#    'doi': 'https://doi.org/10.1097/00005792-199205000-00004',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/1635439'},
#   'label_included': 0},
#  'https://openalex.org/W2007340748': {'ids': {'openalex': 'https://openalex.org/W2007340748',
#    'doi': 'https://doi.org/10.1136/adc.39.205.265',
#    'mag': '2007340748',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/14169457',
#    'pmcid': 'https://www.ncbi.nlm.nih.gov/pmc/articles/2019214'},
#   'label_included': 0},
#  'https://openalex.org/W2057921891': {'ids': {'openalex': 'https://openalex.org/W2057921891',
#    'doi': 'https://doi.org/10.1016/0163-7258(89)90033-8',
#    'mag': '2057921891',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/2672052'},
#   'label_included': 0},
#  'https://openalex.org/W1546322159': {'ids': {'openalex': 'https://openalex.org/W1546322159',
#    'doi': 'https://doi.org/10.1016/s0022-510x(00)00280-x',
#    'mag': '1546322159',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/10865087'},
#   'label_included': 0},
#  'https://openalex.org/W2083997313': {'ids': {'openalex': 'https://openalex.org/W2083997313',
#    'doi': 'https://doi.org/10.1001/archneur.1995.00540280019007',
#    'mag': '2083997313',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/7710368'},
#   'label_included': 0},
#  'https://openalex.org/W2214992806': {'ids': {'openalex': 'https://openalex.org/W2214992806',
#    'doi': 'https://doi.org/10.1016/j.jhep.2015.11.017',
#    'mag': '2214992806',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/26639392'},
#   'label_included': 0},
#  'https://openalex.org/W26289134': {'ids': {'openalex': 'https://openalex.org/W26289134',
#    'mag': '26289134',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/16528929'},
#   'label_included': 0},
#  'https://openalex.org/W2412229368': {'ids': {'openalex': 'https://openalex.org/W2412229368',
#    'mag': '2412229368',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/4084421'},
#   'label_included': 0},
#  'https://openalex.org/W2401016321': {'ids': {'openalex': 'https://openalex.org/W2401016321',
#    'mag': '2401016321',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/715173'},
#   'label_included': 0},
#  'https://openalex.org/W2016020096': {'ids': {'openalex': 'https://openalex.org/W2016020096',
#    'doi': 'https://doi.org/10.1517/13543780802621859',
#    'mag': '2016020096',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/19053885'},
#   'label_included': 0},
#  'https://openalex.org/W2405664443': {'ids': {'openalex': 'https://openalex.org/W2405664443',
#    'mag': '2405664443',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/1358351'},
#   'label_included': 0},
#  'https://openalex.org/W2354746574': {'ids': {'openalex': 'https://openalex.org/W2354746574',
#    'mag': '2354746574',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/11783335'},
#   'label_included': 0},
#  'https://openalex.org/W2078973467': {'ids': {'openalex': 'https://openalex.org/W2078973467',
#    'doi': 'https://doi.org/10.1097/00000441-198612000-00002',
#    'mag': '2078973467',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/3799705'},
#   'label_included': 0},
#  'https://openalex.org/W2400552798': {'ids': {'openalex': 'https://openalex.org/W2400552798',
#    'mag': '2400552798',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/6381924'},
#   'label_included': 0},
#  'https://openalex.org/W2586059431': {'ids': {'openalex': 'https://openalex.org/W2586059431',
#    'doi': 'https://doi.org/10.1016/j.tice.2017.02.001',
#    'mag': '2586059431',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/28222887'},
#   'label_included': 0},
#  'https://openalex.org/W2027883692': {'ids': {'openalex': 'https://openalex.org/W2027883692',
#    'doi': 'https://doi.org/10.2957/kanzo.47.347',
#    'mag': '2027883692'},
#   'label_included': 0},
#  'https://openalex.org/W2272206626': {'ids': {'openalex': 'https://openalex.org/W2272206626',
#    'doi': 'https://doi.org/10.3390/ijms17020196',
#    'mag': '2272206626',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/26861285',
#    'pmcid': 'https://www.ncbi.nlm.nih.gov/pmc/articles/4783930'},
#   'label_included': 0},
#  'https://openalex.org/W1479959272': {'ids': {'openalex': 'https://openalex.org/W1479959272',
#    'doi': 'https://doi.org/10.1016/s0140-6736(68)91814-x',
#    'mag': '1479959272',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/4177386'},
#   'label_included': 0},
#  'https://openalex.org/W1979114037': {'ids': {'openalex': 'https://openalex.org/W1979114037',
#    'doi': 'https://doi.org/10.1111/j.1365-2036.2009.04175.x',
#    'mag': '1979114037',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/19845566'},
#   'label_included': 0},
#  'https://openalex.org/W2136606052': {'ids': {'openalex': 'https://openalex.org/W2136606052',
#    'doi': 'https://doi.org/10.1177/0883073807307972',
#    'mag': '2136606052',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/18056688',
#    'pmcid': 'https://www.ncbi.nlm.nih.gov/pmc/articles/2539109'},
#   'label_included': 0},
#  'https://openalex.org/W2441249774': {'ids': {'openalex': 'https://openalex.org/W2441249774',
#    'mag': '2441249774',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/3063004'},
#   'label_included': 0},
#  'https://openalex.org/W2028739839': {'ids': {'openalex': 'https://openalex.org/W2028739839',
#    'doi': 'https://doi.org/10.1542/pir.28-3-83',
#    'mag': '2028739839',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/17332167'},
#   'label_included': 0},
#  'https://openalex.org/W2028580835': {'ids': {'openalex': 'https://openalex.org/W2028580835',
#    'doi': 'https://doi.org/10.1136/adc.61.11.1068',
#    'mag': '2028580835',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/3789787',
#    'pmcid': 'https://www.ncbi.nlm.nih.gov/pmc/articles/1778125'},
#   'label_included': 0},
#  'https://openalex.org/W2415817190': {'ids': {'openalex': 'https://openalex.org/W2415817190',
#    'mag': '2415817190',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/2965796'},
#   'label_included': 0},
#  'https://openalex.org/W2409823720': {'ids': {'openalex': 'https://openalex.org/W2409823720',
#    'mag': '2409823720',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/4246638'},
#   'label_included': 0},
#  'https://openalex.org/W2047936385': {'ids': {'openalex': 'https://openalex.org/W2047936385',
#    'doi': 'https://doi.org/10.1097/00124509-200403000-00017',
#    'mag': '2047936385',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/15088004'},
#   'label_included': 0},
#  'https://openalex.org/W1986720625': {'ids': {'openalex': 'https://openalex.org/W1986720625',
#    'doi': 'https://doi.org/10.1055/s-0031-1286056',
#    'mag': '1986720625',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/21901655'},
#   'label_included': 0},
#  'https://openalex.org/W2072747057': {'ids': {'openalex': 'https://openalex.org/W2072747057',
#    'doi': 'https://doi.org/10.1016/0162-0134(91)80002-y',
#    'mag': '2072747057',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/2033396'},
#   'label_included': 0},
#  'https://openalex.org/W2014279707': {'ids': {'openalex': 'https://openalex.org/W2014279707',
#    'doi': 'https://doi.org/10.4021/jocmr2010.04.292w',
#    'mag': '2014279707',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/21811529',
#    'pmcid': 'https://www.ncbi.nlm.nih.gov/pmc/articles/3140888'},
#   'label_included': 0},
#  'https://openalex.org/W2414755901': {'ids': {'openalex': 'https://openalex.org/W2414755901',
#    'doi': 'https://doi.org/10.1042/cs0530317',
#    'mag': '2414755901',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/913055'},
#   'label_included': 0},
#  'https://openalex.org/W2076158601': {'ids': {'openalex': 'https://openalex.org/W2076158601',
#    'doi': 'https://doi.org/10.1016/0006-8993(92)91587-5',
#    'mag': '2076158601',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/1393580'},
#   'label_included': 0},
#  'https://openalex.org/W2057802325': {'ids': {'openalex': 'https://openalex.org/W2057802325',
#    'doi': 'https://doi.org/10.1211/0022357991772457',
#    'mag': '2057802325',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/10344628'},
#   'label_included': 0},
#  'https://openalex.org/W2406960316': {'ids': {'openalex': 'https://openalex.org/W2406960316',
#    'mag': '2406960316',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/2784729',
#    'pmcid': 'https://www.ncbi.nlm.nih.gov/pmc/articles/1541856'},
#   'label_included': 0},
#  'https://openalex.org/W2106117593': {'ids': {'openalex': 'https://openalex.org/W2106117593',
#    'doi': 'https://doi.org/10.1017/s1041610205002012',
#    'mag': '2106117593',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/16240489'},
#   'label_included': 0},
#  'https://openalex.org/W2023004731': {'ids': {'openalex': 'https://openalex.org/W2023004731',
#    'doi': 'https://doi.org/10.1538/expanim.54.403',
#    'mag': '2023004731',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/16365517'},
#   'label_included': 0},
#  'https://openalex.org/W2426005388': {'ids': {'openalex': 'https://openalex.org/W2426005388',
#    'mag': '2426005388',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/10383883'},
#   'label_included': 0},
#  'https://openalex.org/W2466941266': {'ids': {'openalex': 'https://openalex.org/W2466941266',
#    'mag': '2466941266',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/3214981'},
#   'label_included': 0},
#  'https://openalex.org/W2313466689': {'ids': {'openalex': 'https://openalex.org/W2313466689',
#    'doi': 'https://doi.org/10.4103/0378-6323.178907',
#    'mag': '2313466689',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/27279318'},
#   'label_included': 0},
#  'https://openalex.org/W1986217382': {'ids': {'openalex': 'https://openalex.org/W1986217382',
#    'doi': 'https://doi.org/10.1016/j.freeradbiomed.2010.10.595',
#    'mag': '1986217382'},
#   'label_included': 0},
#  'https://openalex.org/W2418686127': {'ids': {'openalex': 'https://openalex.org/W2418686127',
#    'mag': '2418686127',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/8091001'},
#   'label_included': 0},
#  'https://openalex.org/W2418805577': {'ids': {'openalex': 'https://openalex.org/W2418805577',
#    'doi': 'https://doi.org/10.1056/nejm197505152922017',
#    'mag': '2418805577',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/1124096'},
#   'label_included': 0},
#  'https://openalex.org/W2411318030': {'ids': {'openalex': 'https://openalex.org/W2411318030',
#    'mag': '2411318030',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/23289267'},
#   'label_included': 0},
#  'https://openalex.org/W169694262': {'ids': {'openalex': 'https://openalex.org/W169694262',
#    'mag': '169694262',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/15727190'},
#   'label_included': 0},
#  'https://openalex.org/W2746694674': {'ids': {'openalex': 'https://openalex.org/W2746694674',
#    'doi': 'https://doi.org/10.3748/wjg.v23.i30.5451',
#    'mag': '2746694674',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/28852304',
#    'pmcid': 'https://www.ncbi.nlm.nih.gov/pmc/articles/5558108'},
#   'label_included': 0},
#  'https://openalex.org/W2041403406': {'ids': {'openalex': 'https://openalex.org/W2041403406',
#    'doi': 'https://doi.org/10.1111/j.1600-0404.1991.tb04936.x',
#    'mag': '2041403406',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/1950459'},
#   'label_included': 0},
#  'https://openalex.org/W2103195615': {'ids': {'openalex': 'https://openalex.org/W2103195615',
#    'doi': 'https://doi.org/10.1002/mds.21761',
#    'mag': '2103195615',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/17960799'},
#   'label_included': 0},
#  'https://openalex.org/W2597821724': {'ids': {'openalex': 'https://openalex.org/W2597821724',
#    'mag': '2597821724'},
#   'label_included': 0},
#  'https://openalex.org/W2003202605': {'ids': {'openalex': 'https://openalex.org/W2003202605',
#    'doi': 'https://doi.org/10.1016/j.yebeh.2010.06.013',
#    'mag': '2003202605',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/20637709'},
#   'label_included': 0},
#  'https://openalex.org/W2020356652': {'ids': {'openalex': 'https://openalex.org/W2020356652',
#    'doi': 'https://doi.org/10.1016/s1353-8020(09)70798-9',
#    'mag': '2020356652',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/20082972'},
#   'label_included': 0},
#  'https://openalex.org/W2129868097': {'ids': {'openalex': 'https://openalex.org/W2129868097',
#    'doi': 'https://doi.org/10.1016/s0035-3787(06)75080-9',
#    'mag': '2129868097',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/16840991'},
#   'label_included': 0},
#  'https://openalex.org/W4302886500': {'ids': {'openalex': 'https://openalex.org/W4302886500',
#    'doi': 'https://doi.org/10.1007/s10545-013-9633-z'},
#   'label_included': 0},
#  'https://openalex.org/W2413944855': {'ids': {'openalex': 'https://openalex.org/W2413944855',
#    'mag': '2413944855',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/7670851'},
#   'label_included': 0},
#  'https://openalex.org/W1997994356': {'ids': {'openalex': 'https://openalex.org/W1997994356',
#    'doi': 'https://doi.org/10.1016/s0022-3476(75)80131-4',
#    'mag': '1997994356',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/1185415'},
#   'label_included': 0},
#  'https://openalex.org/W2159075196': {'ids': {'openalex': 'https://openalex.org/W2159075196',
#    'doi': 'https://doi.org/10.1111/j.1365-2230.1991.tb00386.x',
#    'mag': '2159075196',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/1794180'},
#   'label_included': 0},
#  'https://openalex.org/W1972505088': {'ids': {'openalex': 'https://openalex.org/W1972505088',
#    'doi': 'https://doi.org/10.1007/s00415-002-0867-1',
#    'mag': '1972505088',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/12529799'},
#   'label_included': 0},
#  'https://openalex.org/W2073202193': {'ids': {'openalex': 'https://openalex.org/W2073202193',
#    'doi': 'https://doi.org/10.1001/archneur.1994.00540150106026',
#    'mag': '2073202193',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/8129644'},
#   'label_included': 0},
#  'https://openalex.org/W2791095570': {'ids': {'openalex': 'https://openalex.org/W2791095570',
#    'doi': 'https://doi.org/10.1111/tri.13050',
#    'mag': '2791095570'},
#   'label_included': 0},
#  'https://openalex.org/W2044378080': {'ids': {'openalex': 'https://openalex.org/W2044378080',
#    'doi': 'https://doi.org/10.2169/internalmedicine.50.5209',
#    'mag': '2044378080',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/21757830'},
#   'label_included': 0},
#  'https://openalex.org/W2191735106': {'ids': {'openalex': 'https://openalex.org/W2191735106',
#    'doi': 'https://doi.org/10.1136/bcr-2015-212482',
#    'mag': '2191735106',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/26643186',
#    'pmcid': 'https://www.ncbi.nlm.nih.gov/pmc/articles/4680324'},
#   'label_included': 0},
#  'https://openalex.org/W1995584636': {'ids': {'openalex': 'https://openalex.org/W1995584636',
#    'doi': 'https://doi.org/10.1034/j.1600-0404.2000.101004286.x',
#    'mag': '1995584636',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/10770529'},
#   'label_included': 0},
#  'https://openalex.org/W1989407846': {'ids': {'openalex': 'https://openalex.org/W1989407846',
#    'doi': 'https://doi.org/10.1007/s00249-007-0235-2',
#    'mag': '1989407846',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/18004558'},
#   'label_included': 0},
#  'https://openalex.org/W2003120334': {'ids': {'openalex': 'https://openalex.org/W2003120334',
#    'doi': 'https://doi.org/10.1007/s004670050282',
#    'mag': '2003120334',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/9203178'},
#   'label_included': 0},
#  'https://openalex.org/W2033845344': {'ids': {'openalex': 'https://openalex.org/W2033845344',
#    'doi': 'https://doi.org/10.1176/ajp.124.11.1555',
#    'mag': '2033845344',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/4384740'},
#   'label_included': 0},
#  'https://openalex.org/W2086306720': {'ids': {'openalex': 'https://openalex.org/W2086306720',
#    'doi': 'https://doi.org/10.1159/000231033',
#    'mag': '2086306720',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/4580377'},
#   'label_included': 0},
#  'https://openalex.org/W2091290489': {'ids': {'openalex': 'https://openalex.org/W2091290489',
#    'doi': 'https://doi.org/10.1016/s0022-2143(97)90200-6',
#    'mag': '2091290489',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/9178732'},
#   'label_included': 0},
#  'https://openalex.org/W2466072587': {'ids': {'openalex': 'https://openalex.org/W2466072587',
#    'mag': '2466072587',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/8438601'},
#   'label_included': 0},
#  'https://openalex.org/W2468989451': {'ids': {'openalex': 'https://openalex.org/W2468989451',
#    'mag': '2468989451',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/4070288'},
#   'label_included': 0},
#  'https://openalex.org/W2127240582': {'ids': {'openalex': 'https://openalex.org/W2127240582',
#    'doi': 'https://doi.org/10.4103/0028-3886.121908',
#    'mag': '2127240582',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/24262445'},
#   'label_included': 0},
#  'https://openalex.org/W2010057698': {'ids': {'openalex': 'https://openalex.org/W2010057698',
#    'doi': 'https://doi.org/10.1016/s0028-3843(14)60040-2',
#    'mag': '2010057698',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/20625962'},
#   'label_included': 0},
#  'https://openalex.org/W2018009814': {'ids': {'openalex': 'https://openalex.org/W2018009814',
#    'doi': 'https://doi.org/10.1016/0026-0495(66)90113-2',
#    'mag': '2018009814',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/5933915'},
#   'label_included': 0},
#  'https://openalex.org/W1979500357': {'ids': {'openalex': 'https://openalex.org/W1979500357',
#    'doi': 'https://doi.org/10.1016/s0022-2143(03)00157-4',
#    'mag': '1979500357',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/14713890'},
#   'label_included': 0},
#  'https://openalex.org/W4232221228': {'ids': {'openalex': 'https://openalex.org/W4232221228',
#    'doi': 'https://doi.org/10.1097/01.mpg.0000503536.79797.66',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/27749389'},
#   'label_included': 0},
#  'https://openalex.org/W2883379010': {'ids': {'openalex': 'https://openalex.org/W2883379010',
#    'doi': 'https://doi.org/10.1097/01.tp.0000543911.79351.78',
#    'mag': '2883379010'},
#   'label_included': 0},
#  'https://openalex.org/W2148978968': {'ids': {'openalex': 'https://openalex.org/W2148978968',
#    'doi': 'https://doi.org/10.1248/jhs.57.385',
#    'mag': '2148978968'},
#   'label_included': 0},
#  'https://openalex.org/W256750': {'ids': {'openalex': 'https://openalex.org/W256750',
#    'mag': '256750',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/7727159'},
#   'label_included': 0},
#  'https://openalex.org/W2607657572': {'ids': {'openalex': 'https://openalex.org/W2607657572',
#    'doi': 'https://doi.org/10.1111/jgh.13812',
#    'mag': '2607657572',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/28452067'},
#   'label_included': 0},
#  'https://openalex.org/W2066310622': {'ids': {'openalex': 'https://openalex.org/W2066310622',
#    'doi': 'https://doi.org/10.1097/00000441-197012000-00007',
#    'mag': '2066310622',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/5511397'},
#   'label_included': 0},
#  'https://openalex.org/W1989720958': {'ids': {'openalex': 'https://openalex.org/W1989720958',
#    'doi': 'https://doi.org/10.1159/000114584',
#    'mag': '1989720958',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/5084907'},
#   'label_included': 0},
#  'https://openalex.org/W122083550': {'ids': {'openalex': 'https://openalex.org/W122083550',
#    'mag': '122083550',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/9193846'},
#   'label_included': 0},
#  'https://openalex.org/W2767798137': {'ids': {'openalex': 'https://openalex.org/W2767798137',
#    'doi': 'https://doi.org/10.1016/j.jtemb.2017.11.005',
#    'mag': '2767798137',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/29173477'},
#   'label_included': 0},
#  'https://openalex.org/W2075291906': {'ids': {'openalex': 'https://openalex.org/W2075291906',
#    'doi': 'https://doi.org/10.1159/000070858',
#    'mag': '2075291906',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/12824712'},
#   'label_included': 0},
#  'https://openalex.org/W2017151803': {'ids': {'openalex': 'https://openalex.org/W2017151803',
#    'doi': 'https://doi.org/10.1055/s-2008-1055473',
#    'mag': '2017151803',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/7671785'},
#   'label_included': 0},
#  'https://openalex.org/W2596425071': {'ids': {'openalex': 'https://openalex.org/W2596425071',
#    'doi': 'https://doi.org/10.1007/s00415-010-5575-7',
#    'mag': '2596425071',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/20495927'},
#   'label_included': 0},
#  'https://openalex.org/W2328537337': {'ids': {'openalex': 'https://openalex.org/W2328537337',
#    'doi': 'https://doi.org/10.3748/wjg.v3.i4.260',
#    'mag': '2328537337',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/27053888',
#    'pmcid': 'https://www.ncbi.nlm.nih.gov/pmc/articles/4806256'},
#   'label_included': 0},
#  'https://openalex.org/W1972855643': {'ids': {'openalex': 'https://openalex.org/W1972855643',
#    'doi': 'https://doi.org/10.1002/jtra.10045',
#    'mag': '1972855643'},
#   'label_included': 0},
#  'https://openalex.org/W1970675898': {'ids': {'openalex': 'https://openalex.org/W1970675898',
#    'doi': 'https://doi.org/10.1111/j.1365-2230.1985.tb00588.x',
#    'mag': '1970675898',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/4042411'},
#   'label_included': 0},
#  'https://openalex.org/W1983353239': {'ids': {'openalex': 'https://openalex.org/W1983353239',
#    'doi': 'https://doi.org/10.2478/s11536-010-0004-y',
#    'mag': '1983353239'},
#   'label_included': 0},
#  'https://openalex.org/W2140346666': {'ids': {'openalex': 'https://openalex.org/W2140346666',
#    'doi': 'https://doi.org/10.1136/adc.60.7.656',
#    'mag': '2140346666',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/4026362',
#    'pmcid': 'https://www.ncbi.nlm.nih.gov/pmc/articles/1777290'},
#   'label_included': 0},
#  'https://openalex.org/W2097809603': {'ids': {'openalex': 'https://openalex.org/W2097809603',
#    'doi': 'https://doi.org/10.1034/j.1399-3046.2002.1r069.x',
#    'mag': '2097809603',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/11906637'},
#   'label_included': 0},
#  'https://openalex.org/W2058926864': {'ids': {'openalex': 'https://openalex.org/W2058926864',
#    'doi': 'https://doi.org/10.1590/1516-4446-2013-1188',
#    'mag': '2058926864',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/24963514'},
#   'label_included': 0},
#  'https://openalex.org/W1981833536': {'ids': {'openalex': 'https://openalex.org/W1981833536',
#    'doi': 'https://doi.org/10.1001/archderm.112.9.1267',
#    'mag': '1981833536',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/136925'},
#   'label_included': 0},
#  'https://openalex.org/W2236118418': {'ids': {'openalex': 'https://openalex.org/W2236118418',
#    'doi': 'https://doi.org/10.1097/mpg.0000000000001084',
#    'mag': '2236118418',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/26690865'},
#   'label_included': 0},
#  'https://openalex.org/W2437129639': {'ids': {'openalex': 'https://openalex.org/W2437129639',
#    'mag': '2437129639',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/14101489'},
#   'label_included': 0},
#  'https://openalex.org/W2047036516': {'ids': {'openalex': 'https://openalex.org/W2047036516',
#    'doi': 'https://doi.org/10.1097/mpg.0000000000000628',
#    'mag': '2047036516',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/25825851'},
#   'label_included': 0},
#  'https://openalex.org/W2409330604': {'ids': {'openalex': 'https://openalex.org/W2409330604',
#    'mag': '2409330604',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/8202418'},
#   'label_included': 0},
#  'https://openalex.org/W2046607770': {'ids': {'openalex': 'https://openalex.org/W2046607770',
#    'doi': 'https://doi.org/10.1111/j.0924-2708.2006.00108.x',
#    'mag': '2046607770',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/26991983'},
#   'label_included': 0},
#  'https://openalex.org/W2170647585': {'ids': {'openalex': 'https://openalex.org/W2170647585',
#    'doi': 'https://doi.org/10.1157/13094353',
#    'mag': '2170647585',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/17129551'},
#   'label_included': 0},
#  'https://openalex.org/W2784337732': {'ids': {'openalex': 'https://openalex.org/W2784337732',
#    'doi': 'https://doi.org/10.1007/s10072-018-3257-x',
#    'mag': '2784337732',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/29356957'},
#   'label_included': 0},
#  'https://openalex.org/W2112516482': {'ids': {'openalex': 'https://openalex.org/W2112516482',
#    'doi': 'https://doi.org/10.5350/dajpn2013260310',
#    'mag': '2112516482'},
#   'label_included': 0},
#  'https://openalex.org/W2169737231': {'ids': {'openalex': 'https://openalex.org/W2169737231',
#    'doi': 'https://doi.org/10.1177/1756285612471700',
#    'mag': '2169737231',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/23483632',
#    'pmcid': 'https://www.ncbi.nlm.nih.gov/pmc/articles/3582311'},
#   'label_included': 0},
#  'https://openalex.org/W2074267102': {'ids': {'openalex': 'https://openalex.org/W2074267102',
#    'doi': 'https://doi.org/10.1097/00000441-198611000-00007',
#    'mag': '2074267102',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/3777013'},
#   'label_included': 0},
#  'https://openalex.org/W2400804268': {'ids': {'openalex': 'https://openalex.org/W2400804268',
#    'mag': '2400804268',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/13943419'},
#   'label_included': 0},
#  'https://openalex.org/W2397961220': {'ids': {'openalex': 'https://openalex.org/W2397961220',
#    'mag': '2397961220',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/16729535'},
#   'label_included': 0},
#  'https://openalex.org/W1999046011': {'ids': {'openalex': 'https://openalex.org/W1999046011',
#    'doi': 'https://doi.org/10.4103/0019-5545.82556',
#    'mag': '1999046011',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/21772656',
#    'pmcid': 'https://www.ncbi.nlm.nih.gov/pmc/articles/3136026'},
#   'label_included': 0},
#  'https://openalex.org/W1990195431': {'ids': {'openalex': 'https://openalex.org/W1990195431',
#    'doi': 'https://doi.org/10.1136/jcp.51.2.169',
#    'mag': '1990195431',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/9602696',
#    'pmcid': 'https://www.ncbi.nlm.nih.gov/pmc/articles/500517'},
#   'label_included': 0},
#  'https://openalex.org/W122745426': {'ids': {'openalex': 'https://openalex.org/W122745426',
#    'doi': 'https://doi.org/10.1093/qjmed/42.3.619',
#    'mag': '122745426',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/4199472'},
#   'label_included': 1},
#  'https://openalex.org/W2318638564': {'ids': {'openalex': 'https://openalex.org/W2318638564',
#    'doi': 'https://doi.org/10.1055/s-0032-1323784',
#    'mag': '2318638564',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/23037949'},
#   'label_included': 0},
#  'https://openalex.org/W2422778013': {'ids': {'openalex': 'https://openalex.org/W2422778013',
#    'mag': '2422778013',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/14208076'},
#   'label_included': 0},
#  'https://openalex.org/W2464609433': {'ids': {'openalex': 'https://openalex.org/W2464609433',
#    'mag': '2464609433',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/2350924'},
#   'label_included': 0},
#  'https://openalex.org/W2725225667': {'ids': {'openalex': 'https://openalex.org/W2725225667',
#    'doi': 'https://doi.org/10.3390/ijms18071456',
#    'mag': '2725225667',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/28684721',
#    'pmcid': 'https://www.ncbi.nlm.nih.gov/pmc/articles/5535947'},
#   'label_included': 0},
#  'https://openalex.org/W2061830345': {'ids': {'openalex': 'https://openalex.org/W2061830345',
#    'doi': 'https://doi.org/10.1007/bf00442196',
#    'mag': '2061830345',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/913436'},
#   'label_included': 0},
#  'https://openalex.org/W2415025527': {'ids': {'openalex': 'https://openalex.org/W2415025527',
#    'mag': '2415025527',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/12185935'},
#   'label_included': 0},
#  'https://openalex.org/W2066911354': {'ids': {'openalex': 'https://openalex.org/W2066911354',
#    'doi': 'https://doi.org/10.1136/bmj.2.5973.726-a',
#    'mag': '2066911354',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/1139195',
#    'pmcid': 'https://www.ncbi.nlm.nih.gov/pmc/articles/1673956'},
#   'label_included': 0},
#  'https://openalex.org/W14542269': {'ids': {'openalex': 'https://openalex.org/W14542269',
#    'mag': '14542269',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/19338486'},
#   'label_included': 0},
#  'https://openalex.org/W2416870389': {'ids': {'openalex': 'https://openalex.org/W2416870389',
#    'mag': '2416870389',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/6324360'},
#   'label_included': 0},
#  'https://openalex.org/W4255107534': {'ids': {'openalex': 'https://openalex.org/W4255107534',
#    'doi': 'https://doi.org/10.1016/s1090-3798(99)90979-0',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/10595669'},
#   'label_included': 0},
#  'https://openalex.org/W2011949795': {'ids': {'openalex': 'https://openalex.org/W2011949795',
#    'doi': 'https://doi.org/10.2165/11591370-000000000-00000',
#    'mag': '2011949795',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/21770477'},
#   'label_included': 0},
#  'https://openalex.org/W2050684576': {'ids': {'openalex': 'https://openalex.org/W2050684576',
#    'doi': 'https://doi.org/10.1016/j.dld.2014.07.113',
#    'mag': '2050684576'},
#   'label_included': 0},
#  'https://openalex.org/W2215596087': {'ids': {'openalex': 'https://openalex.org/W2215596087',
#    'doi': 'https://doi.org/10.4254/wjh.v7.i29.2859',
#    'mag': '2215596087',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/26692151',
#    'pmcid': 'https://www.ncbi.nlm.nih.gov/pmc/articles/4678372'},
#   'label_included': 0},
#  'https://openalex.org/W2514159521': {'ids': {'openalex': 'https://openalex.org/W2514159521',
#    'doi': 'https://doi.org/10.1212/con.0000000000000346',
#    'mag': '2514159521',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/27495202'},
#   'label_included': 0},
#  'https://openalex.org/W2010069299': {'ids': {'openalex': 'https://openalex.org/W2010069299',
#    'doi': 'https://doi.org/10.1111/j.1600-0404.1984.tb07816.x',
#    'mag': '2010069299',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/6464668'},
#   'label_included': 0},
#  'https://openalex.org/W4244714845': {'ids': {'openalex': 'https://openalex.org/W4244714845',
#    'doi': 'https://doi.org/10.1038/ajg.2012.271'},
#   'label_included': 0},
#  'https://openalex.org/W2402491810': {'ids': {'openalex': 'https://openalex.org/W2402491810',
#    'mag': '2402491810',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/2814676'},
#   'label_included': 0},
#  'https://openalex.org/W1768948929': {'ids': {'openalex': 'https://openalex.org/W1768948929',
#    'doi': 'https://doi.org/10.1128/jb.181.19.5891-5897.1999',
#    'mag': '1768948929',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/10498699',
#    'pmcid': 'https://www.ncbi.nlm.nih.gov/pmc/articles/103614'},
#   'label_included': 0},
#  'https://openalex.org/W2067108010': {'ids': {'openalex': 'https://openalex.org/W2067108010',
#    'doi': 'https://doi.org/10.5114/ninp.2013.36763',
#    'mag': '2067108010',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/23986430'},
#   'label_included': 0},
#  'https://openalex.org/W2086668141': {'ids': {'openalex': 'https://openalex.org/W2086668141',
#    'doi': 'https://doi.org/10.5009/gnl.2013.7.4.500',
#    'mag': '2086668141',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/23898395',
#    'pmcid': 'https://www.ncbi.nlm.nih.gov/pmc/articles/3724043'},
#   'label_included': 0},
#  'https://openalex.org/W2286292607': {'ids': {'openalex': 'https://openalex.org/W2286292607',
#    'mag': '2286292607',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/2627165'},
#   'label_included': 0},
#  'https://openalex.org/W163772750': {'ids': {'openalex': 'https://openalex.org/W163772750',
#    'doi': 'https://doi.org/10.1007/bf00399003',
#    'mag': '163772750',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/503243'},
#   'label_included': 0},
#  'https://openalex.org/W4300031226': {'ids': {'openalex': 'https://openalex.org/W4300031226',
#    'doi': 'https://doi.org/10.1111/jnc.13692'},
#   'label_included': 0},
#  'https://openalex.org/W2116131674': {'ids': {'openalex': 'https://openalex.org/W2116131674',
#    'doi': 'https://doi.org/10.2174/1570180811666140322001829',
#    'mag': '2116131674'},
#   'label_included': 0},
#  'https://openalex.org/W1981899748': {'ids': {'openalex': 'https://openalex.org/W1981899748',
#    'doi': 'https://doi.org/10.1016/s0140-6736(58)92567-4',
#    'mag': '1981899748',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/13503211'},
#   'label_included': 0},
#  'https://openalex.org/W2415987482': {'ids': {'openalex': 'https://openalex.org/W2415987482',
#    'mag': '2415987482',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/1144877'},
#   'label_included': 0},
#  'https://openalex.org/W4292361613': {'ids': {'openalex': 'https://openalex.org/W4292361613',
#    'doi': 'https://doi.org/10.1002/mds.25051',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/22714688'},
#   'label_included': 0},
#  'https://openalex.org/W1965552756': {'ids': {'openalex': 'https://openalex.org/W1965552756',
#    'doi': 'https://doi.org/10.1016/s0210-5705(03)70340-9',
#    'mag': '1965552756',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/12525328'},
#   'label_included': 0},
#  'https://openalex.org/W2412621155': {'ids': {'openalex': 'https://openalex.org/W2412621155',
#    'mag': '2412621155',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/1152537'},
#   'label_included': 0},
#  'https://openalex.org/W4252421362': {'ids': {'openalex': 'https://openalex.org/W4252421362',
#    'doi': 'https://doi.org/10.1007/s12291-015-0537-6'},
#   'label_included': 0},
#  'https://openalex.org/W2808078858': {'ids': {'openalex': 'https://openalex.org/W2808078858',
#    'doi': 'https://doi.org/10.1186/s12883-018-1085-5',
#    'mag': '2808078858',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/29907136',
#    'pmcid': 'https://www.ncbi.nlm.nih.gov/pmc/articles/6002982'},
#   'label_included': 0},
#  'https://openalex.org/W2316249438': {'ids': {'openalex': 'https://openalex.org/W2316249438',
#    'doi': 'https://doi.org/10.1016/j.jceh.2014.02.128',
#    'mag': '2316249438'},
#   'label_included': 0},
#  'https://openalex.org/W2410197788': {'ids': {'openalex': 'https://openalex.org/W2410197788',
#    'mag': '2410197788',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/7565403'},
#   'label_included': 0},
#  'https://openalex.org/W1517300596': {'ids': {'openalex': 'https://openalex.org/W1517300596',
#    'doi': 'https://doi.org/10.3748/wjg.v10.i1.42',
#    'mag': '1517300596',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/14695766',
#    'pmcid': 'https://www.ncbi.nlm.nih.gov/pmc/articles/4717075'},
#   'label_included': 0},
#  'https://openalex.org/W2134784779': {'ids': {'openalex': 'https://openalex.org/W2134784779',
#    'doi': 'https://doi.org/10.1016/s1665-2681(19)30872-5',
#    'mag': '2134784779',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/24756018'},
#   'label_included': 0},
#  'https://openalex.org/W2103861837': {'ids': {'openalex': 'https://openalex.org/W2103861837',
#    'doi': 'https://doi.org/10.4269/ajtmh.2007.77.560',
#    'mag': '2103861837',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/17827379'},
#   'label_included': 0},
#  'https://openalex.org/W2596674939': {'ids': {'openalex': 'https://openalex.org/W2596674939',
#    'doi': 'https://doi.org/10.2165/11591610-000000000-00000',
#    'mag': '2596674939',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/21999649'},
#   'label_included': 0},
#  'https://openalex.org/W4211141606': {'ids': {'openalex': 'https://openalex.org/W4211141606',
#    'doi': 'https://doi.org/10.1002/ajmg.c.30310',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/21766437'},
#   'label_included': 0},
#  'https://openalex.org/W2016814293': {'ids': {'openalex': 'https://openalex.org/W2016814293',
#    'doi': 'https://doi.org/10.1002/jtra.1051',
#    'mag': '2016814293'},
#   'label_included': 0},
#  'https://openalex.org/W2092236974': {'ids': {'openalex': 'https://openalex.org/W2092236974',
#    'doi': 'https://doi.org/10.1021/ja106206z',
#    'mag': '2092236974',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/21155609'},
#   'label_included': 0},
#  'https://openalex.org/W219064652': {'ids': {'openalex': 'https://openalex.org/W219064652',
#    'mag': '219064652',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/8259463'},
#   'label_included': 0},
#  'https://openalex.org/W3188505668': {'ids': {'openalex': 'https://openalex.org/W3188505668',
#    'doi': 'https://doi.org/10.1007/s11011-005-7910-8',
#    'mag': '3188505668',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/16382340'},
#   'label_included': 0},
#  'https://openalex.org/W2460180033': {'ids': {'openalex': 'https://openalex.org/W2460180033',
#    'doi': 'https://doi.org/10.1080/17843286.1960.11717624',
#    'mag': '2460180033',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/13708400'},
#   'label_included': 0},
#  'https://openalex.org/W2008952207': {'ids': {'openalex': 'https://openalex.org/W2008952207',
#    'doi': 'https://doi.org/10.1016/s0304-3940(99)00258-x',
#    'mag': '2008952207',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/10336172'},
#   'label_included': 0},
#  'https://openalex.org/W1983144628': {'ids': {'openalex': 'https://openalex.org/W1983144628',
#    'doi': 'https://doi.org/10.1111/j.1600-0404.1989.tb03720.x',
#    'mag': '1983144628',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/2711817'},
#   'label_included': 0},
#  'https://openalex.org/W2398223082': {'ids': {'openalex': 'https://openalex.org/W2398223082',
#    'doi': 'https://doi.org/10.1001/archsurg.137.7.865',
#    'mag': '2398223082',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/12093348'},
#   'label_included': 0},
#  'https://openalex.org/W2321298194': {'ids': {'openalex': 'https://openalex.org/W2321298194',
#    'doi': 'https://doi.org/10.1016/j.jns.2013.07.2448',
#    'mag': '2321298194'},
#   'label_included': 0},
#  'https://openalex.org/W2110189088': {'ids': {'openalex': 'https://openalex.org/W2110189088',
#    'doi': 'https://doi.org/10.1016/j.clineuro.2006.01.008',
#    'mag': '2110189088',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/16545904'},
#   'label_included': 0},
#  'https://openalex.org/W2045645689': {'ids': {'openalex': 'https://openalex.org/W2045645689',
#    'doi': 'https://doi.org/10.1080/07315724.1990.10720405',
#    'mag': '2045645689',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/2258535'},
#   'label_included': 0},
#  'https://openalex.org/W2146771335': {'ids': {'openalex': 'https://openalex.org/W2146771335',
#    'doi': 'https://doi.org/10.1111/nyas.12379',
#    'mag': '2146771335',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/24611802'},
#   'label_included': 0},
#  'https://openalex.org/W1983761594': {'ids': {'openalex': 'https://openalex.org/W1983761594',
#    'doi': 'https://doi.org/10.1111/j.1365-2141.1986.tb02250.x',
#    'mag': '1983761594',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/3801328'},
#   'label_included': 0},
#  'https://openalex.org/W1973056370': {'ids': {'openalex': 'https://openalex.org/W1973056370',
#    'doi': 'https://doi.org/10.2174/092986706776055742',
#    'mag': '1973056370',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/16515519'},
#   'label_included': 0},
#  'https://openalex.org/W4292577873': {'ids': {'openalex': 'https://openalex.org/W4292577873',
#    'doi': 'https://doi.org/10.1002/mds.26295',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/26095114'},
#   'label_included': 0},
#  'https://openalex.org/W2146280863': {'ids': {'openalex': 'https://openalex.org/W2146280863',
#    'doi': 'https://doi.org/10.1046/j.1442-200x.1999.01090.x',
#    'mag': '2146280863',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/10453201'},
#   'label_included': 0},
#  'https://openalex.org/W2109552352': {'ids': {'openalex': 'https://openalex.org/W2109552352',
#    'doi': 'https://doi.org/10.1002/hep.20893',
#    'mag': '2109552352',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/16175588'},
#   'label_included': 0},
#  'https://openalex.org/W2089363298': {'ids': {'openalex': 'https://openalex.org/W2089363298',
#    'doi': 'https://doi.org/10.1111/j.1600-0404.1992.tb04017.x',
#    'mag': '2089363298',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/1574992'},
#   'label_included': 0},
#  'https://openalex.org/W2007466716': {'ids': {'openalex': 'https://openalex.org/W2007466716',
# ...
#    'doi': 'https://doi.org/10.1016/j.paed.2009.09.006',
#    'mag': '2157528563'},
#   'label_included': 0},
#  'https://openalex.org/W204172411': {'ids': {'openalex': 'https://openalex.org/W204172411',
#    'mag': '204172411',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/20112850'},
#   'label_included': 0},
#  'https://openalex.org/W2264162825': {'ids': {'openalex': 'https://openalex.org/W2264162825',
#    'doi': 'https://doi.org/10.1186/s40360-015-0031-z',
#    'mag': '2264162825',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/26589720',
#    'pmcid': 'https://www.ncbi.nlm.nih.gov/pmc/articles/4654910'},
#   'label_included': 0},
#  'https://openalex.org/W3152190237': {'ids': {'openalex': 'https://openalex.org/W3152190237',
#    'mag': '3152190237',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/1633017'},
#   'label_included': 0},
#  'https://openalex.org/W2429011564': {'ids': {'openalex': 'https://openalex.org/W2429011564',
#    'mag': '2429011564',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/10932536'},
#   'label_included': 0},
#  'https://openalex.org/W1988934234': {'ids': {'openalex': 'https://openalex.org/W1988934234',
#    'doi': 'https://doi.org/10.7326/0003-4819-115-9-720',
#    'mag': '1988934234',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/1929042'},
#   'label_included': 0},
#  'https://openalex.org/W2461720743': {'ids': {'openalex': 'https://openalex.org/W2461720743',
#    'mag': '2461720743',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/5468376'},
#   'label_included': 0},
#  'https://openalex.org/W2431845713': {'ids': {'openalex': 'https://openalex.org/W2431845713',
#    'mag': '2431845713',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/2697201'},
#   'label_included': 0},
#  'https://openalex.org/W2425097814': {'ids': {'openalex': 'https://openalex.org/W2425097814',
#    'mag': '2425097814',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/18310797'},
#   'label_included': 0},
#  'https://openalex.org/W2425582913': {'ids': {'openalex': 'https://openalex.org/W2425582913',
#    'mag': '2425582913',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/7094098'},
#   'label_included': 0},
#  'https://openalex.org/W2596946034': {'ids': {'openalex': 'https://openalex.org/W2596946034',
#    'doi': 'https://doi.org/10.1007/s10545-017-0030-x',
#    'mag': '2596946034',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/28303424'},
#   'label_included': 0},
#  'https://openalex.org/W2405198579': {'ids': {'openalex': 'https://openalex.org/W2405198579',
#    'mag': '2405198579',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/6062332'},
#   'label_included': 0},
#  'https://openalex.org/W2415502310': {'ids': {'openalex': 'https://openalex.org/W2415502310',
#    'mag': '2415502310',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/7233355'},
#   'label_included': 0},
#  'https://openalex.org/W2606516760': {'ids': {'openalex': 'https://openalex.org/W2606516760',
#    'doi': 'https://doi.org/10.1016/j.neuro.2017.04.006',
#    'mag': '2606516760',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/28416395'},
#   'label_included': 0},
#  'https://openalex.org/W2417148534': {'ids': {'openalex': 'https://openalex.org/W2417148534',
#    'mag': '2417148534',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/14318784'},
#   'label_included': 0},
#  'https://openalex.org/W4235366646': {'ids': {'openalex': 'https://openalex.org/W4235366646',
#    'doi': 'https://doi.org/10.3748/wjg.v19.i43.7630',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/24282352'},
#   'label_included': 0},
#  'https://openalex.org/W2412146871': {'ids': {'openalex': 'https://openalex.org/W2412146871',
#    'mag': '2412146871',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/10216413'},
#   'label_included': 0},
#  'https://openalex.org/W2171029771': {'ids': {'openalex': 'https://openalex.org/W2171029771',
#    'doi': 'https://doi.org/10.1016/s0140-6736(87)92753-x',
#    'mag': '2171029771',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/2885586'},
#   'label_included': 0},
#  'https://openalex.org/W4252579175': {'ids': {'openalex': 'https://openalex.org/W4252579175',
#    'doi': 'https://doi.org/10.1038/ajg.2017.351',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/28981031'},
#   'label_included': 0},
#  'https://openalex.org/W1983066436': {'ids': {'openalex': 'https://openalex.org/W1983066436',
#    'doi': 'https://doi.org/10.1016/j.tox.2007.02.016',
#    'mag': '1983066436',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/17408840'},
#   'label_included': 0},
#  'https://openalex.org/W2187002394': {'ids': {'openalex': 'https://openalex.org/W2187002394',
#    'mag': '2187002394'},
#   'label_included': 0},
#  'https://openalex.org/W2440463154': {'ids': {'openalex': 'https://openalex.org/W2440463154',
#    'mag': '2440463154',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/14056737'},
#   'label_included': 0},
#  'https://openalex.org/W2586820959': {'ids': {'openalex': 'https://openalex.org/W2586820959',
#    'doi': 'https://doi.org/10.5272/jimab.2017231.1447',
#    'mag': '2586820959'},
#   'label_included': 0},
#  'https://openalex.org/W2046662033': {'ids': {'openalex': 'https://openalex.org/W2046662033',
#    'doi': 'https://doi.org/10.1021/bi000101+',
#    'mag': '2046662033',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/10858308'},
#   'label_included': 0},
#  'https://openalex.org/W2132631287': {'ids': {'openalex': 'https://openalex.org/W2132631287',
#    'doi': 'https://doi.org/10.1620/tjem.123.279',
#    'mag': '2132631287',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/601776'},
#   'label_included': 0},
#  'https://openalex.org/W2465161032': {'ids': {'openalex': 'https://openalex.org/W2465161032',
#    'mag': '2465161032',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/4732090'},
#   'label_included': 0},
#  'https://openalex.org/W2048831483': {'ids': {'openalex': 'https://openalex.org/W2048831483',
#    'doi': 'https://doi.org/10.4103/0019-5359.27975',
#    'mag': '2048831483',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/17090869'},
#   'label_included': 0},
#  'https://openalex.org/W2765295927': {'ids': {'openalex': 'https://openalex.org/W2765295927',
#    'doi': 'https://doi.org/10.3389/fneur.2017.00559',
#    'mag': '2765295927',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/29163329',
#    'pmcid': 'https://www.ncbi.nlm.nih.gov/pmc/articles/5671475'},
#   'label_included': 0},
#  'https://openalex.org/W2301070268': {'ids': {'openalex': 'https://openalex.org/W2301070268',
#    'doi': 'https://doi.org/10.4103/0976-3147.178653',
#    'mag': '2301070268',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/27114677',
#    'pmcid': 'https://www.ncbi.nlm.nih.gov/pmc/articles/4821954'},
#   'label_included': 0},
#  'https://openalex.org/W4248578981': {'ids': {'openalex': 'https://openalex.org/W4248578981',
#    'doi': 'https://doi.org/10.1053/j.ajkd.2012.02.177'},
#   'label_included': 0},
#  'https://openalex.org/W2156928936': {'ids': {'openalex': 'https://openalex.org/W2156928936',
#    'doi': 'https://doi.org/10.1002/mds.25901',
#    'mag': '2156928936',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/24797888'},
#   'label_included': 0},
#  'https://openalex.org/W2334759085': {'ids': {'openalex': 'https://openalex.org/W2334759085',
#    'doi': 'https://doi.org/10.1097/mcg.0000000000000248',
#    'mag': '2334759085',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/25291347'},
#   'label_included': 0},
#  'https://openalex.org/W160692870': {'ids': {'openalex': 'https://openalex.org/W160692870',
#    'doi': 'https://doi.org/10.1080/00325481.1992.11701346',
#    'mag': '160692870',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/1589371'},
#   'label_included': 0},
#  'https://openalex.org/W2988615119': {'ids': {'openalex': 'https://openalex.org/W2988615119',
#    'doi': 'https://doi.org/10.1016/s1089-3261(05)70362-7',
#    'mag': '2988615119',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/15560044'},
#   'label_included': 0},
#  'https://openalex.org/W4290317162': {'ids': {'openalex': 'https://openalex.org/W4290317162',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/2602537'},
#   'label_included': 0},
#  'https://openalex.org/W2424896533': {'ids': {'openalex': 'https://openalex.org/W2424896533',
#    'mag': '2424896533',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/6755575'},
#   'label_included': 0},
#  'https://openalex.org/W2735794745': {'ids': {'openalex': 'https://openalex.org/W2735794745',
#    'doi': 'https://doi.org/10.1016/j.jceh.2017.05.202',
#    'mag': '2735794745'},
#   'label_included': 0},
#  'https://openalex.org/W2079423332': {'ids': {'openalex': 'https://openalex.org/W2079423332',
#    'doi': 'https://doi.org/10.1212/01.wnl.0000234130.27871.03',
#    'mag': '2079423332',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/16966556'},
#   'label_included': 0},
#  'https://openalex.org/W2414372639': {'ids': {'openalex': 'https://openalex.org/W2414372639',
#    'mag': '2414372639',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/7850252'},
#   'label_included': 0},
#  'https://openalex.org/W2409889383': {'ids': {'openalex': 'https://openalex.org/W2409889383',
#    'mag': '2409889383',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/7300488'},
#   'label_included': 0},
#  'https://openalex.org/W107324294': {'ids': {'openalex': 'https://openalex.org/W107324294',
#    'mag': '107324294',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/10869138'},
#   'label_included': 0},
#  'https://openalex.org/W2029304389': {'ids': {'openalex': 'https://openalex.org/W2029304389',
#    'doi': 'https://doi.org/10.1159/000007894',
#    'mag': '2029304389',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/9476721'},
#   'label_included': 0},
#  'https://openalex.org/W2060079257': {'ids': {'openalex': 'https://openalex.org/W2060079257',
#    'doi': 'https://doi.org/10.1212/01.wnl.0000144192.30426.38',
#    'mag': '2060079257',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/15557537'},
#   'label_included': 0},
#  'https://openalex.org/W2207510817': {'ids': {'openalex': 'https://openalex.org/W2207510817',
#    'doi': 'https://doi.org/10.1016/j.clinre.2015.07.003',
#    'mag': '2207510817',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/26601640'},
#   'label_included': 0},
#  'https://openalex.org/W2417573589': {'ids': {'openalex': 'https://openalex.org/W2417573589',
#    'mag': '2417573589',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/17330175'},
#   'label_included': 0},
#  'https://openalex.org/W2803594708': {'ids': {'openalex': 'https://openalex.org/W2803594708',
#    'doi': 'https://doi.org/10.1056/nejmp1800861',
#    'mag': '2803594708',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/29768140'},
#   'label_included': 0},
#  'https://openalex.org/W2415530918': {'ids': {'openalex': 'https://openalex.org/W2415530918',
#    'mag': '2415530918',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/5756864'},
#   'label_included': 0},
#  'https://openalex.org/W2179867099': {'ids': {'openalex': 'https://openalex.org/W2179867099',
#    'doi': 'https://doi.org/10.1146/annurev.nu.05.070185.002013',
#    'mag': '2179867099',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/3896271'},
#   'label_included': 0},
#  'https://openalex.org/W2056734775': {'ids': {'openalex': 'https://openalex.org/W2056734775',
#    'doi': 'https://doi.org/10.1159/000171218',
#    'mag': '2056734775',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/2663256'},
#   'label_included': 0},
#  'https://openalex.org/W2038084978': {'ids': {'openalex': 'https://openalex.org/W2038084978',
#    'doi': 'https://doi.org/10.1007/s00247-008-1017-4',
#    'mag': '2038084978',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/18839167'},
#   'label_included': 0},
#  'https://openalex.org/W2417747352': {'ids': {'openalex': 'https://openalex.org/W2417747352',
#    'mag': '2417747352',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/4358747'},
#   'label_included': 0},
#  'https://openalex.org/W2133582182': {'ids': {'openalex': 'https://openalex.org/W2133582182',
#    'doi': 'https://doi.org/10.1111/j.1872-034x.2010.00754.x',
#    'mag': '2133582182',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/21338455'},
#   'label_included': 0},
#  'https://openalex.org/W2067033022': {'ids': {'openalex': 'https://openalex.org/W2067033022',
#    'doi': 'https://doi.org/10.2165/00003495-199039060-00002',
#    'mag': '2067033022',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/2196164'},
#   'label_included': 0},
#  'https://openalex.org/W2080279294': {'ids': {'openalex': 'https://openalex.org/W2080279294',
#    'doi': 'https://doi.org/10.1212/cpj.0b013e318278be1e',
#    'mag': '2080279294',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/30123682',
#    'pmcid': 'https://www.ncbi.nlm.nih.gov/pmc/articles/5829478'},
#   'label_included': 0},
#  'https://openalex.org/W2253495972': {'ids': {'openalex': 'https://openalex.org/W2253495972',
#    'mag': '2253495972',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/13489633',
#    'pmcid': 'https://www.ncbi.nlm.nih.gov/pmc/articles/1829554'},
#   'label_included': 0},
#  'https://openalex.org/W2124740220': {'ids': {'openalex': 'https://openalex.org/W2124740220',
#    'doi': 'https://doi.org/10.1517/14728222.7.3.405',
#    'mag': '2124740220',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/12783576'},
#   'label_included': 0},
#  'https://openalex.org/W4300024732': {'ids': {'openalex': 'https://openalex.org/W4300024732',
#    'doi': 'https://doi.org/10.1111/j.1468-1331.2012.03889.x'},
#   'label_included': 0},
#  'https://openalex.org/W2463871544': {'ids': {'openalex': 'https://openalex.org/W2463871544',
#    'mag': '2463871544',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/271391'},
#   'label_included': 0},
#  'https://openalex.org/W2220788058': {'ids': {'openalex': 'https://openalex.org/W2220788058',
#    'doi': 'https://doi.org/10.1016/j.gene.2015.05.067',
#    'mag': '2220788058',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/26031236'},
#   'label_included': 0},
#  'https://openalex.org/W2401292806': {'ids': {'openalex': 'https://openalex.org/W2401292806',
#    'mag': '2401292806',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/4060799'},
#   'label_included': 0},
#  'https://openalex.org/W1888918572': {'ids': {'openalex': 'https://openalex.org/W1888918572',
#    'doi': 'https://doi.org/10.1093/oxfordjournals.qjmed.a067495',
#    'mag': '1888918572',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/866569'},
#   'label_included': 0},
#  'https://openalex.org/W2058835240': {'ids': {'openalex': 'https://openalex.org/W2058835240',
#    'doi': 'https://doi.org/10.1136/jnnp.2009.204651',
#    'mag': '2058835240',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/20660913'},
#   'label_included': 0},
#  'https://openalex.org/W2050825349': {'ids': {'openalex': 'https://openalex.org/W2050825349',
#    'doi': 'https://doi.org/10.2165/00003495-199549010-00007',
#    'mag': '2050825349',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/7705218'},
#   'label_included': 0},
#  'https://openalex.org/W2110000830': {'ids': {'openalex': 'https://openalex.org/W2110000830',
#    'doi': 'https://doi.org/10.1016/s0140-6736(08)60876-4',
#    'mag': '2110000830',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/18555919'},
#   'label_included': 0},
#  'https://openalex.org/W2118500754': {'ids': {'openalex': 'https://openalex.org/W2118500754',
#    'doi': 'https://doi.org/10.1093/oxfordjournals.qjmed.a067346',
#    'mag': '2118500754',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/4728043'},
#   'label_included': 0},
#  'https://openalex.org/W2412427014': {'ids': {'openalex': 'https://openalex.org/W2412427014',
#    'mag': '2412427014',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/14224682'},
#   'label_included': 0},
#  'https://openalex.org/W2462565411': {'ids': {'openalex': 'https://openalex.org/W2462565411',
#    'mag': '2462565411',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/14191274'},
#   'label_included': 0},
#  'https://openalex.org/W2409828791': {'ids': {'openalex': 'https://openalex.org/W2409828791',
#    'mag': '2409828791',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/4835809'},
#   'label_included': 0},
#  'https://openalex.org/W2271470592': {'ids': {'openalex': 'https://openalex.org/W2271470592',
#    'doi': 'https://doi.org/10.1016/j.injr.2015.12.004',
#    'mag': '2271470592'},
#   'label_included': 0},
#  'https://openalex.org/W2071928217': {'ids': {'openalex': 'https://openalex.org/W2071928217',
#    'doi': 'https://doi.org/10.1016/j.jtemb.2013.09.006',
#    'mag': '2071928217',
#    'pmid': 'https://pubmed.ncbi.nlm.nih.gov/24188895'},
#   'label_included': 0},
#  ...}
